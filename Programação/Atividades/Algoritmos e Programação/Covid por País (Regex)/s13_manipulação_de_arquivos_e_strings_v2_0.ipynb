# %% [markdown]
# # Manipulação de Arquivos e Strings

# %% [markdown]
# ### Semana 13 | Uso do Regex

# %% [markdown]
# ## Questão Dirigida

# %% [markdown]
# Como gravar em um arquivo CSV os dados da pandemia de COVID-19 por país desta [página](https://pt.wikipedia.org/wiki/Portal:COVID-19) da Wikipedia?

# %% [markdown]
# ## Desenvolvimento do Projeto

# %% [markdown]
# Para desenvolver este projeto, vamos utilizar técnicas de raspagem de dados na Web (Web Scraping), com a biblioteca `requests`, `BeautifulSoup` e expressões regulares.

# %%
# download
import requests

# parsing do HTML
from bs4 import BeautifulSoup

# expressões regulares
import re

# %% [markdown]
# A incidência de COVID-19 por país pode ser encontrada na página da Wikipedia.

# %%
# URL de análise
url_pagina = 'https://pt.wikipedia.org/wiki/Portal:COVID-19'

# %%
# Utiliza a biblioteca requests para fazer o download da pagina HTML
pagina_html = requests.get(url_pagina)

# O Código 200 indica que o download foi bem sucedido
pagina_html
# Out:
# <Response [200]>

# %%
# O Beautiful Soup 
soup = BeautifulSoup(pagina_html.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="pt">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Portal:COVID-19 – Wikipédia, a enciclopédia livre
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":[",\t."," \t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","janeiro","fevereiro","março","abril","maio","junho","julho","agosto","setembro","outubro","novembro","dezembro"],"wgRequestId":"8b69c4d3-37ef-4855-bd88-b02590485a56","wgCSPNonce":!1,"wgCanonicalNamespace":"Portal","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":100,"wgPageName":"Portal:COVID-19","wgTitle":"COVID-19","wgCurRevisionId":58084687,"wgRevisionId":58084687,"wgArticleId":6223270,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["!Páginas com argumentos formatnum não numéricos","!CS1 francês-fontes em língua (fr)","!CS1 usa script na língua russo (ru)","!CS1 russo-fontes em língua (ru)","!CS1 italiano-fontes em língua (it)","!CS1 espanhol-fontes em língua (es)","!CS1 alemão-fontes em língua (de)"
# ,"!CS1 polaco-fontes em língua (pl)","!CS1 usa script na língua ucraniano (uk)","!CS1 ucraniano-fontes em língua (uk)","!CS1 checo-fontes em língua (cs)","!CS1 neerlandês-fontes em língua (nl)","!Páginas com citações usando parâmetros sem suporte","!Páginas com erros CS1: título traduzido","!CS1 manut: Falta pipe","!CS1 árabe-fontes em língua (ar)","!CS1 romeno-fontes em língua (ro)","!CS1 sueco-fontes em língua (sv)","!CS1 usa script na língua hebraico (he)","!CS1 hebraico-fontes em língua (he)","!CS1 usa script na língua bengalês (bn)","!CS1 bengalês-fontes em língua (bn)","!CS1 usa script na língua japonês (ja)","!CS1 japonês-fontes em língua (ja)","!CS1 malaio-fontes em língua (ms)","!CS1 usa script na língua árabe (ar)","!CS1 usa script na língua búlgaro (bg)","!CS1 búlgaro-fontes em língua (bg)","!CS1 usa script na língua grego (el)","!CS1 grego-fontes em língua (el)","!CS1 cazaque-fontes em língua (kk)",
# "!CS1 azerbaijano-fontes em língua (az)","!CS1 dinamarquês-fontes em língua (da)","!CS1 lituano-fontes em língua (lt)","!CS1 amárico-fontes em língua (am)","!CS1 esloveno-fontes em língua (sl)","!CS1 usa script na língua arménio (hy)","!CS1 arménio-fontes em língua (hy)","!CS1 macedónio-fontes em língua (mk)","!CS1 usa script na língua tailandês (th)","!CS1 tailandês-fontes em língua (th)","!CS1 albanês-fontes em língua (sq)","!CS1 letão-fontes em língua (lv)","!CS1 fontes em língua estrangeira (ISO 639-2)","!CS1 usa script na língua chinês (zh)","!CS1 chinês-fontes em língua (zh)","!CS1 inglês-fontes em língua (en)","!CS1 khmer-fontes em língua (km)","!CS1 catalão-fontes em língua (ca)","!CS1 turco-fontes em língua (tr)","!CS1 islandês-fontes em língua (is)","!CS1 vietnamita-fontes em língua (vi)","!CS1 somali-fontes em língua (so)","!CS1 laosiano-fontes em língua (lo)","!Portais destacados","!CS1 usa script em língua estrangeira",
# "!Portais sobre ciência","!Portal Medicina"],"wgPageContentLanguage":"pt","wgPageContentModel":"wikitext","wgRelevantPageName":"Portal:COVID-19","wgRelevantArticleId":6223270,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsFlags":10,"wgVisualEditor":{"pageLanguageCode":"pt","pageLanguageDir":"ltr","pageVariantFallbacks":"pt"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!0},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"português","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgGENewcomerTasksGuidanceEnabled":!0,"wgGEAskQuestionEnabled":!0,"wgGELinkRecommendationsFrontendEnabled":!1,"wgWikibaseItemId":"Q87829288","wgSiteNoticeId":"2.30"};RLSTATE={"ext.globalCssJs.user.styles":"ready",
# "site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","mediawiki.ui.button":"ready","skins.vector.styles":"ready","skins.vector.icons":"ready","mediawiki.ui.icon":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready","ext.dismissableSiteNotice.styles":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","skins.vector.js","ext.gadget.Topicon","ext.gadget.Metacaixa","ext.gadget.TitleRewrite","ext.gadget.ElementosOcultaveis","ext.gadget.FeedbackHighlight","ext.gadget.ReferenceTooltips","ext.gadget.NewVillagePump","ext.gadget.wikibugs","ext.gadget.charinsert","ext.gadget.requestForAdminship","ext.gadget.EnhancedSearch",
# "ext.gadget.WikiMiniAtlas","ext.gadget.PagesForDeletion","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.dismissableSiteNotice"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});mw.user.options.set({"variant":"pt"});
# });});
#   </script>
#   <link href="/w/load.php?lang=pt&amp;modules=ext.cite.styles%7Cext.dismissableSiteNotice.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.ui.button%2Cicon%7Cskins.vector.icons%2Cstyles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=pt&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=pt&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.37.0-wmf.7" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="Portal:COVID-19 – Wikipédia, a enciclopédia livre" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <link href="//upload.wikimedia.org" rel="preconnect"/>
#   <link href="//pt.m.wikipedia.org/wiki/Portal:COVID-19" media="only screen and (max-width: 720px)" rel="alternate"/>
#   <link href="/w/index.php?title=Portal:COVID-19&amp;action=edit" rel="alternate" title="Editar" type="application/x-wiki"/>
#   <link href="/w/index.php?title=Portal:COVID-19&amp;action=edit" rel="edit" title="Editar"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipédia (pt)" type="application/opensearchdescription+xml"/>
#   <link href="//pt.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="https://pt.wikipedia.org/wiki/Portal:COVID-19" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-100 ns-subject mw-editable page-Portal_COVID-19 rootpage-Portal_COVID-19 skin-vector action-view skin-vector-search-vue">
#   <div class="mw-page-container">
#    <a class="mw-jump-link" href="#content">
#     Saltar para o conteúdo
#    </a>
#    <div class="mw-page-container-inner">
#     <input checked="" class="mw-checkbox-hack-checkbox" id="mw-sidebar-checkbox" type="checkbox"/>
#     <header class="mw-header">
#      <label aria-controls="mw-panel" class="mw-checkbox-hack-button mw-ui-icon mw-ui-icon-element" data-event-name="ui.sidebar" for="mw-sidebar-checkbox" id="mw-sidebar-button" role="button" tabindex="0">
#       Alternar barra lateral
#      </label>
#      <a class="mw-logo" href="/wiki/Wikip%C3%A9dia:P%C3%A1gina_principal">
#       <img alt="" aria-hidden="true" class="mw-logo-icon" height="50" src="/static/images/mobile/copyright/wikipedia-pt-20.png" width="50"/>
#       <span class="mw-logo-container">
#        <img alt="Wikipédia" class="mw-logo-wordmark" height="30" src="/static/images/mobile/copyright/wikipedia-wordmark-pt-20.svg" width="119"/>
#        <img alt="" class="mw-logo-tagline" height="13" src="/static/images/mobile/copyright/wikipedia-tagline-pt.svg" width="113"/>
#       </span>
#      </a>
#      <div class="p-search--show-thumbnail" id="p-search" role="search">
#       <h3>
#        <label for="searchInput">
#         Busca
#        </label>
#       </h3>
#       <form action="/w/index.php" id="searchform">
#        <div data-search-loc="header-moved" id="simpleSearch">
#         <input accesskey="f" autocapitalize="sentences" id="searchInput" name="search" placeholder="Pesquisar na Wikipédia" title="Pesquisar na Wikipédia [f]" type="search">
#          <input name="title" type="hidden" value="Especial:Pesquisar"/>
#          <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Procurar páginas que contêm este texto" type="submit" value="Pesquisar"/>
#          <input class="searchButton" id="searchButton" name="go" title="Ir para uma página com este nome exacto, caso exista" type="submit" value="Ir"/>
#         </input>
#        </div>
#       </form>
#      </div>
#      <nav aria-labelledby="p-personal-label" class="mw-portlet mw-portlet-personal vector-user-menu-legacy vector-menu" id="p-personal" role="navigation">
#       <h3 class="vector-menu-heading" id="p-personal-label">
#        <span>
#         Ferramentas pessoais
#        </span>
#       </h3>
#       <div class="vector-menu-content">
#        <ul class="vector-menu-content-list">
#         <li id="pt-anonuserpage">
#          Não autenticado
#         </li>
#         <li id="pt-anontalk">
#          <a accesskey="n" href="/wiki/Especial:Minha_discuss%C3%A3o" title="Discussão sobre edições feitas a partir deste endereço IP [n]">
#           Discussão
#          </a>
#         </li>
#         <li id="pt-anoncontribs">
#          <a accesskey="y" href="/wiki/Especial:Minhas_contribui%C3%A7%C3%B5es" title="Uma lista de edições feitas a partir deste endereço IP [y]">
#           Contribuições
#          </a>
#         </li>
#         <li id="pt-createaccount">
#          <a href="/w/index.php?title=Especial:Criar_conta&amp;returnto=Portal%3ACOVID-19" title="É encorajado a criar uma conta e iniciar sessão; no entanto, não é obrigatório">
#           Criar uma conta
#          </a>
#         </li>
#         <li id="pt-login">
#          <a accesskey="o" href="/w/index.php?title=Especial:Entrar&amp;returnto=Portal%3ACOVID-19" title="Aconselhamos-lhe a criar uma conta na Wikipédia, embora tal não seja obrigatório. [o]">
#           Entrar
#          </a>
#         </li>
#        </ul>
#       </div>
#      </nav>
#     </header>
#     <div class="mw-workspace-container">
#      <div id="mw-navigation">
#       <h2>
#        Menu de navegação
#       </h2>
#       <div class="mw-sidebar" id="mw-panel">
#        <nav aria-labelledby="p-navigation-label" class="mw-portlet mw-portlet-navigation vector-menu vector-menu-portal portal" id="p-navigation" role="navigation">
#         <h3 class="vector-menu-heading" id="p-navigation-label">
#          <span>
#           Navegação
#          </span>
#         </h3>
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#           <li id="n-mainpage-description">
#            <a accesskey="z" href="/wiki/Wikip%C3%A9dia:P%C3%A1gina_principal" title="Visitar a página principal [z]">
#             Página principal
#            </a>
#           </li>
#           <li id="n-featuredcontent">
#            <a href="/wiki/Portal:Conte%C3%BAdo_destacado">
#             Conteúdo destacado
#            </a>
#           </li>
#           <li id="n-currentevents">
#            <a href="/wiki/Portal:Eventos_atuais" title="Informação temática sobre eventos atuais">
#             Eventos atuais
#            </a>
#           </li>
#           <li id="n-villagepump">
#            <a href="/wiki/Wikip%C3%A9dia:Esplanada">
#             Esplanada
#            </a>
#           </li>
#           <li id="n-randompage">
#            <a accesskey="x" href="/wiki/Especial:Aleat%C3%B3ria" title="Carregar página aleatória [x]">
#             Página aleatória
#            </a>
#           </li>
#           <li id="n-portals">
#            <a href="/wiki/Portal:%C3%8Dndice">
#             Portais
#            </a>
#           </li>
#           <li id="n-bug_in_article">
#            <a href="/wiki/Wikip%C3%A9dia:Informe_um_erro">
#             Informar um erro
#            </a>
#           </li>
#          </ul>
#         </div>
#        </nav>
#        <nav aria-labelledby="p-interaction-label" class="mw-portlet mw-portlet-interaction vector-menu vector-menu-portal portal" id="p-interaction" role="navigation">
#         <h3 class="vector-menu-heading" id="p-interaction-label">
#          <span>
#           Colaboração
#          </span>
#         </h3>
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#           <li id="n-welcome">
#            <a href="/wiki/Wikip%C3%A9dia:Boas-vindas">
#             Boas-vindas
#            </a>
#           </li>
#           <li id="n-help">
#            <a href="/wiki/Ajuda:P%C3%A1gina_principal" title="Um local reservado para auxílio.">
#             Ajuda
#            </a>
#           </li>
#           <li id="n-testpage">
#            <a href="/wiki/Ajuda:P%C3%A1gina_de_testes">
#             Página de testes
#            </a>
#           </li>
#           <li id="n-portal">
#            <a href="/wiki/Wikip%C3%A9dia:Portal_comunit%C3%A1rio" title="Sobre o projeto">
#             Portal comunitário
#            </a>
#           </li>
#           <li id="n-recentchanges">
#            <a accesskey="r" href="/wiki/Especial:Mudan%C3%A7as_recentes" title="Uma lista de mudanças recentes nesta wiki [r]">
#             Mudanças recentes
#            </a>
#           </li>
#           <li id="n-maintenance">
#            <a href="/wiki/Wikip%C3%A9dia:Manuten%C3%A7%C3%A3o">
#             Manutenção
#            </a>
#           </li>
#           <li id="n-createpage">
#            <a href="/wiki/Ajuda:Guia_de_edi%C3%A7%C3%A3o/Como_come%C3%A7ar_uma_p%C3%A1gina">
#             Criar página
#            </a>
#           </li>
#           <li id="n-newpages-description">
#            <a href="/wiki/Especial:P%C3%A1ginas_novas">
#             Páginas novas
#            </a>
#           </li>
#           <li id="n-contact-description">
#            <a href="/wiki/Wikip%C3%A9dia:Contato">
#             Contato
#            </a>
#           </li>
#           <li id="n-sitesupport">
#            <a href="//donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=20120521SB001&amp;uselang=pt" title="Ajude-nos">
#             Donativos
#            </a>
#           </li>
#          </ul>
#         </div>
#        </nav>
#        <nav aria-labelledby="p-tb-label" class="mw-portlet mw-portlet-tb vector-menu vector-menu-portal portal" id="p-tb" role="navigation">
#         <h3 class="vector-menu-heading" id="p-tb-label">
#          <span>
#           Ferramentas
#          </span>
#         </h3>
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#           <li id="t-whatlinkshere">
#            <a accesskey="j" href="/wiki/Especial:P%C3%A1ginas_afluentes/Portal:COVID-19" title="Lista de todas as páginas que contêm hiperligações para esta [j]">
#             Páginas afluentes
#            </a>
#           </li>
#           <li id="t-recentchangeslinked">
#            <a accesskey="k" href="/wiki/Especial:Altera%C3%A7%C3%B5es_relacionadas/Portal:COVID-19" rel="nofollow" title="Mudanças recentes nas páginas para as quais esta contém hiperligações [k]">
#             Alterações relacionadas
#            </a>
#           </li>
#           <li id="t-upload">
#            <a accesskey="u" href="/wiki/Wikipedia:Carregar_ficheiro" title="Carregar ficheiros [u]">
#             Carregar ficheiro
#            </a>
#           </li>
#           <li id="t-specialpages">
#            <a accesskey="q" href="/wiki/Especial:P%C3%A1ginas_especiais" title="Lista de páginas especiais [q]">
#             Páginas especiais
#            </a>
#           </li>
#           <li id="t-permalink">
#            <a href="/w/index.php?title=Portal:COVID-19&amp;oldid=58084687" title="Hiperligação permanente para esta revisão da página">
#             Hiperligação permanente
#            </a>
#           </li>
#           <li id="t-info">
#            <a href="/w/index.php?title=Portal:COVID-19&amp;action=info" title="Mais informações sobre esta página">
#             Informações da página
#            </a>
#           </li>
#           <li id="t-wikibase">
#            <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q87829288" title="Hiperligação para o elemento do repositório de dados [g]">
#             Elemento Wikidata
#            </a>
#           </li>
#          </ul>
#         </div>
#        </nav>
#        <nav aria-labelledby="p-coll-print_export-label" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
#         <h3 class="vector-menu-heading" id="p-coll-print_export-label">
#          <span>
#           Imprimir/exportar
#          </span>
#         </h3>
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#           <li id="coll-create_a_book">
#            <a href="/w/index.php?title=Especial:Livro&amp;bookcmd=book_creator&amp;referer=Portal%3ACOVID-19">
#             Criar um livro
#            </a>
#           </li>
#           <li id="coll-download-as-rl">
#            <a href="/w/index.php?title=Especial:DownloadAsPdf&amp;page=Portal%3ACOVID-19&amp;action=show-download-screen">
#             Descarregar como PDF
#            </a>
#           </li>
#           <li id="t-print">
#            <a accesskey="p" href="/w/index.php?title=Portal:COVID-19&amp;printable=yes" title="Versão para impressão desta página [p]">
#             Versão para impressão
#            </a>
#           </li>
#          </ul>
#         </div>
#        </nav>
#        <nav aria-labelledby="p-wikibase-otherprojects-label" class="mw-portlet mw-portlet-wikibase-otherprojects vector-menu vector-menu-portal portal" id="p-wikibase-otherprojects" role="navigation">
#         <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
#          <span>
#           Noutros projetos
#          </span>
#         </h3>
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#           <li class="wb-otherproject-link wb-otherproject-wikinews">
#            <a href="https://pt.wikinews.org/wiki/Portal:COVID-19" hreflang="pt">
#             Wikinotícias
#            </a>
#           </li>
#          </ul>
#         </div>
#        </nav>
#        <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
#         <h3 class="vector-menu-heading" id="p-lang-label">
#          <span>
#           Noutras línguas
#          </span>
#         </h3>
#         <div class="vector-menu-content">
#          <ul class="vector-menu-content-list">
#           <li class="interlanguage-link interwiki-ar">
#            <a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D8%A8%D9%88%D8%A7%D8%A8%D8%A9:%D9%83%D9%88%D9%81%D9%8A%D8%AF-19" hreflang="ar" lang="ar" title="بوابة:كوفيد-19 — árabe">
#             العربية
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-bn">
#            <a class="interlanguage-link-target" href="https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A7%8D%E0%A6%B0%E0%A6%AC%E0%A7%87%E0%A6%B6%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A6%BE%E0%A6%B0:%E0%A6%95%E0%A6%B0%E0%A7%8B%E0%A6%A8%E0%A6%BE%E0%A6%AD%E0%A6%BE%E0%A6%87%E0%A6%B0%E0%A6%BE%E0%A6%B8_%E0%A6%B0%E0%A7%8B%E0%A6%97_%E0%A7%A8%E0%A7%A6%E0%A7%A7%E0%A7%AF" hreflang="bn" lang="bn" title="প্রবেশদ্বার:করোনাভাইরাস রোগ ২০১৯ — bengalês">
#             বাংলা
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-de">
#            <a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Portal:COVID-19" hreflang="de" lang="de" title="Portal:COVID-19 — alemão">
#             Deutsch
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-en">
#            <a class="interlanguage-link-target" href="https://en.wikipedia.org/wiki/Portal:COVID-19" hreflang="en" lang="en" title="Portal:COVID-19 — inglês">
#             English
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-es">
#            <a class="interlanguage-link-target" href="https://es.wikipedia.org/wiki/Portal:COVID-19" hreflang="es" lang="es" title="Portal:COVID-19 — espanhol">
#             Español
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-fr">
#            <a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/Portail:Maladie_%C3%A0_coronavirus_2019" hreflang="fr" lang="fr" title="Portail:Maladie à coronavirus 2019 — francês">
#             Français
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-id">
#            <a class="interlanguage-link-target" href="https://id.wikipedia.org/wiki/Portal:Penyakit_koronavirus_2019" hreflang="id" lang="id" title="Portal:Penyakit koronavirus 2019 — indonésio">
#             Bahasa Indonesia
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-ms">
#            <a class="interlanguage-link-target" href="https://ms.wikipedia.org/wiki/Portal:Penyakit_koronavirus_2019" hreflang="ms" lang="ms" title="Portal:Penyakit koronavirus 2019 — malaio">
#             Bahasa Melayu
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-sd">
#            <a class="interlanguage-link-target" href="https://sd.wikipedia.org/wiki/%D8%A8%D8%A7%D8%A8:%DA%AA%D9%88%D8%B1%D9%88%D9%86%D8%A7_%D9%88%D8%A7%D8%A6%D8%B1%D8%B3_%D9%85%D8%B1%D8%B6_2019" hreflang="sd" lang="sd" title="باب:ڪورونا وائرس مرض 2019 — sindi">
#             سنڌي
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-si">
#            <a class="interlanguage-link-target" href="https://si.wikipedia.org/wiki/%E0%B6%AF%E0%B7%8A%E0%B7%80%E0%B7%8F%E0%B6%BB%E0%B6%BA:%E0%B6%9A%E0%B7%9C%E0%B7%80%E0%B7%92%E0%B6%A9%E0%B7%8A-19" hreflang="si" lang="si" title="ද්වාරය:කොවිඩ්-19 — cingalês">
#             සිංහල
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-ur">
#            <a class="interlanguage-link-target" href="https://ur.wikipedia.org/wiki/%D8%A8%D8%A7%D8%A8:%DA%A9%D9%88%D8%B1%D9%88%D9%86%D8%A7_%D9%88%D8%A7%D8%A6%D8%B1%D8%B3_%D9%85%D8%B1%D8%B6_2019%D8%A1" hreflang="ur" lang="ur" title="باب:کورونا وائرس مرض 2019ء — urdu">
#             اردو
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-uz">
#            <a class="interlanguage-link-target" href="https://uz.wikipedia.org/wiki/Portal:COVID-19" hreflang="uz" lang="uz" title="Portal:COVID-19 — usbeque">
#             Oʻzbekcha/ўзбекча
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-vi">
#            <a class="interlanguage-link-target" href="https://vi.wikipedia.org/wiki/Ch%E1%BB%A7_%C4%91%E1%BB%81:COVID-19" hreflang="vi" lang="vi" title="Chủ đề:COVID-19 — vietnamita">
#             Tiếng Việt
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-zh">
#            <a class="interlanguage-link-target" href="https://zh.wikipedia.org/wiki/Portal:2019%E5%86%A0%E7%8A%B6%E7%97%85%E6%AF%92%E7%97%85" hreflang="zh" lang="zh" title="Portal:2019冠状病毒病 — chinês">
#             中文
#            </a>
#           </li>
#           <li class="interlanguage-link interwiki-zh-yue">
#            <a class="interlanguage-link-target" href="https://zh-yue.wikipedia.org/wiki/Portal:%E6%AD%A6%E6%BC%A2%E8%82%BA%E7%82%8E" hreflang="yue" lang="yue" title="Portal:武漢肺炎 — Cantonese">
#             粵語
#            </a>
#           </li>
#          </ul>
#          <div class="after-portlet after-portlet-lang">
#           <span class="wb-langlinks-edit wb-langlinks-link">
#            <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q87829288#sitelinks-wikipedia" title="Editar hiperligações interlínguas">
#             Editar hiperligações
#            </a>
#           </span>
#          </div>
#         </div>
#        </nav>
#       </div>
#       <div id="mw-head">
#        <div class="mw-article-toolbar-container">
#         <div id="left-navigation">
#          <nav aria-labelledby="p-namespaces-label" class="mw-portlet mw-portlet-namespaces vector-menu vector-menu-tabs" id="p-namespaces" role="navigation">
#           <h3 class="vector-menu-heading" id="p-namespaces-label">
#            <span>
#             Espaços nominais
#            </span>
#           </h3>
#           <div class="vector-menu-content">
#            <ul class="vector-menu-content-list">
#             <li class="selected" id="ca-nstab-portal">
#              <a accesskey="p" href="/wiki/Portal:COVID-19" title="Ver o Portal [p]">
#               Portal
#              </a>
#             </li>
#             <li id="ca-talk">
#              <a accesskey="t" href="/wiki/Portal_Discuss%C3%A3o:COVID-19" rel="discussion" title="Discussão sobre o conteúdo da página [t]">
#               Discussão
#              </a>
#             </li>
#            </ul>
#           </div>
#          </nav>
#          <nav aria-labelledby="p-variants-label" class="mw-portlet mw-portlet-variants emptyPortlet vector-menu vector-menu-dropdown" id="p-variants" role="navigation">
#           <input aria-labelledby="p-variants-label" class="vector-menu-checkbox" type="checkbox"/>
#           <h3 class="vector-menu-heading" id="p-variants-label">
#            <span>
#             Variantes
#            </span>
#           </h3>
#           <div class="vector-menu-content">
#            <ul class="vector-menu-content-list">
#            </ul>
#           </div>
#          </nav>
#         </div>
#         <div id="right-navigation">
#          <nav aria-labelledby="p-views-label" class="mw-portlet mw-portlet-views vector-menu vector-menu-tabs" id="p-views" role="navigation">
#           <h3 class="vector-menu-heading" id="p-views-label">
#            <span>
#             Vistas
#            </span>
#           </h3>
#           <div class="vector-menu-content">
#            <ul class="vector-menu-content-list">
#             <li class="selected" id="ca-view">
#              <a href="/wiki/Portal:COVID-19">
#               Ler
#              </a>
#             </li>
#             <li id="ca-edit">
#              <a accesskey="e" href="/w/index.php?title=Portal:COVID-19&amp;action=edit" title="Editar esta página [e]">
#               Editar código-fonte
#              </a>
#             </li>
#             <li id="ca-history">
#              <a accesskey="h" href="/w/index.php?title=Portal:COVID-19&amp;action=history" title="Edições anteriores desta página. [h]">
#               Ver histórico
#              </a>
#             </li>
#            </ul>
#           </div>
#          </nav>
#          <nav aria-labelledby="p-cactions-label" class="mw-portlet mw-portlet-cactions emptyPortlet vector-menu vector-menu-dropdown" id="p-cactions" role="navigation">
#           <input aria-labelledby="p-cactions-label" class="vector-menu-checkbox" type="checkbox"/>
#           <h3 class="vector-menu-heading" id="p-cactions-label">
#            <span>
#             Mais
#            </span>
#           </h3>
#           <div class="vector-menu-content">
#            <ul class="vector-menu-content-list">
#            </ul>
#           </div>
#          </nav>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="mw-content-container">
#       <main class="mw-body" id="content" role="main">
#        <a id="top">
#        </a>
#        <div id="siteNotice">
#         <!-- CentralNotice -->
#         <div id="mw-dismissablenotice-anonplace">
#         </div>
#         <script>
#          (function(){var node=document.getElementById("mw-dismissablenotice-anonplace");if(node){node.outerHTML="\u003Cdiv class=\"mw-dismissable-notice\"\u003E\u003Cdiv class=\"mw-dismissable-notice-close\"\u003E[\u003Ca tabindex=\"0\" role=\"button\"\u003Eocultar\u003C/a\u003E]\u003C/div\u003E\u003Cdiv class=\"mw-dismissable-notice-body\"\u003E\u003Cdiv id=\"localNotice\" lang=\"pt\" dir=\"ltr\"\u003E\u003Cdiv style=\"position: relative; text-align: left; margin-bottom: 10px; overflow: hidden; box-sizing: border-box; -webkit-box-sizing: border-box; box-sizing: border-box;\"\u003E\n \u003Cdiv class=\"top-banner-20\"\u003E\u003C/div\u003E\n    \u003Cdiv style=\"display: table; font-family: -apple-system, BlinkMacSystemFont, \u0026#39;Segoe UI\u0026#39;, Roboto, Lato, Helvetica, Arial, sans-serif; width: 100%; padding: 25px 20px 25px 0; border: 1px solid #c8ccd1; border-radius: 2px; background: none; -webkit-box-sizing: border-box; box-sizing: border-box;\"\u003E\n        \u003Cdiv style=\"display: table-row; height: 100%; -webkit-box-sizing: border-box; box-sizing: border-box;\"\u003E\u003Cspan style=\"display: table-cell; width: 150px; height: 90px; vertical-align: middle; text-align: center;\"\u003E\u003Cspan style=\"height:100%; margin-left: 10px;\"\u003E\u003Ca href=\"/wiki/Ficheiro:WP20Symbols_CAKE1.svg\" class=\"image\"\u003E\u003Cimg alt=\"WP20Symbols CAKE1.svg\" src=\"//upload.wikimedia.org/wikipedia/commons/thumb/a/a3/WP20Symbols_CAKE1.svg/116px-WP20Symbols_CAKE1.svg.png\" decoding=\"async\" width=\"116\" height=\"91\" srcset=\"//upload.wikimedia.org/wikipedia/commons/thumb/a/a3/WP20Symbols_CAKE1.svg/174px-WP20Symbols_CAKE1.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a3/WP20Symbols_CAKE1.svg/232px-WP20Symbols_CAKE1.svg.png 2x\" data-file-width=\"512\" data-file-height=\"401\" /\u003E\u003C/a\u003E\u003C/span\u003E\u003C/span\u003E\u003Cspan style=\"vertical-align: middle; font-size: 16px; line-height: 1.375; z-index: 1; display: table-cell; background: #fff;\"\u003E \n           \u003Ca href=\"/wiki/Wikip%C3%A9dia:20_anos\" title=\"Wikipédia:20 anos\"\u003E\u003Cspan style=\"font-weight: bold; color: #222; font-size: 110%;\"\u003EÉ o aniversário da Wikipédia em português!\u003C/span\u003E\u003C/a\u003E\u003Cbr /\u003E\u003Ca href=\"/wiki/Wikip%C3%A9dia:20_anos\" title=\"Wikipédia:20 anos\"\u003E\u003Cspan style=\"color: #222; font-weight: 600; text-decoration: underline;\"\u003EJunte-se à celebração e venha desejar um feliz aniversário à Wikipédia.\u003C/span\u003E\u003C/a\u003E\u003Cbr /\u003E\u003Ca href=\"/wiki/Wikip%C3%A9dia:Comunicado_sobre_vinte_anos\" title=\"Wikipédia:Comunicado sobre vinte anos\"\u003E\u003Cb style=\"color: Dark red; font-size: 1.3em; display: table-cell;\"\u003ELeia o texto completo de nosso comunicado\u003C/b\u003E\u003C/a\u003E\u003C/span\u003E\u003C/div\u003E\u003C/div\u003E\u003Cdiv class=\"bottom-banner-20\"\u003E\u003C/div\u003E\u003C/div\u003E\u003C/div\u003E\u003C/div\u003E\u003C/div\u003E";}}());
#         </script>
#        </div>
#        <div class="mw-indicators">
#         <div class="mw-indicator" id="mw-indicator-featured-star">
#          <a href="/wiki/Wikip%C3%A9dia:Portais_destacados" title="Este é um portal destacado. Clique aqui para mais informações.">
#           <img alt="Este é um portal destacado. Clique aqui para mais informações." data-file-height="438" data-file-width="462" decoding="async" height="19" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Cscr-featured1.png/20px-Cscr-featured1.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Cscr-featured1.png/30px-Cscr-featured1.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/bc/Cscr-featured1.png/40px-Cscr-featured1.png 2x" width="20"/>
#          </a>
#         </div>
#        </div>
#        <h1 class="firstHeading" id="firstHeading">
#         Portal:COVID-19
#        </h1>
#        <div class="vector-body" id="bodyContent">
#         <div class="noprint" id="siteSub">
#          Origem: Wikipédia, a enciclopédia livre.
#         </div>
#         <div id="contentSub">
#         </div>
#         <div id="contentSub2">
#         </div>
#         <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="pt">
#          <div class="mw-parser-output">
#           <table style="width:100%;background:#ECF0FC">
#            <tbody>
#             <tr>
#              <td style="border-bottom:none;padding:0.5em;width:100%; background:#4169E1;">
#               <span style="font-weight:bold; font-size:100%;color:#FFFFFF;">
#                <div style="text-align:center;">
#                 <span style="font-size:larger;">
#                  Portal da COVID-19
#                 </span>
#                </div>
#               </span>
#              </td>
#             </tr>
#             <tr>
#              <td style="padding:0.5em; vertical-align:top; background:#FFFFFF;margin-bottom:-0.5em;padding-top:0.5em; padding-left:1em">
#               <div class="thumb tright">
#                <div class="thumbinner" style="width:302px;">
#                 <a class="image" href="/w/index.php?title=Ficheiro:Symptoms_of_coronavirus_disease_2019.svg&amp;lang=pt">
#                  <img alt="" class="thumbimage" data-file-height="1171" data-file-width="1879" decoding="async" height="187" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Symptoms_of_coronavirus_disease_2019.svg/langpt-300px-Symptoms_of_coronavirus_disease_2019.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Symptoms_of_coronavirus_disease_2019.svg/langpt-450px-Symptoms_of_coronavirus_disease_2019.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Symptoms_of_coronavirus_disease_2019.svg/langpt-600px-Symptoms_of_coronavirus_disease_2019.svg.png 2x" width="300"/>
#                 </a>
#                 <div class="thumbcaption">
#                  <div class="magnify">
#                   <a class="internal" href="/wiki/Ficheiro:Symptoms_of_coronavirus_disease_2019.svg" title="Ampliar">
#                   </a>
#                  </div>
#                  Sintomas mais comuns de COVID-19
#                 </div>
#                </div>
#               </div>
#               <p>
#                <b>
#                 <a href="/wiki/COVID-19" title="COVID-19">
#                  COVID-19
#                 </a>
#                </b>
#                (do inglês
#                <i>
#                 Coronavirus Disease 2019
#                </i>
#                ) é uma
#                <a class="mw-redirect" href="/wiki/Doen%C3%A7a_infeciosa" title="Doença infeciosa">
#                 doença infeciosa
#                </a>
#                causada pelo
#                <a href="/wiki/Coronav%C3%ADrus_da_s%C3%ADndrome_respirat%C3%B3ria_aguda_grave_2" title="Coronavírus da síndrome respiratória aguda grave 2">
#                 coronavírus da síndrome respiratória aguda grave 2
#                </a>
#                (SARS-CoV-2). Os sintomas mais comuns são
#                <a href="/wiki/Febre" title="Febre">
#                 febre
#                </a>
#                ,
#                <a href="/wiki/Tosse" title="Tosse">
#                 tosse
#                </a>
#                e
#                <a class="mw-redirect" href="/wiki/Falta_de_ar" title="Falta de ar">
#                 dificuldade em respirar
#                </a>
#                .
#               </p>
#               <p>
#                Cerca de 80% dos casos confirmados são ligeiros ou
#                <a href="/wiki/Assintom%C3%A1tico" title="Assintomático">
#                 assintomáticos
#                </a>
#                e a maioria recupera sem sequelas.No entanto, 15% são infeções graves que necessitam de
#                <a href="/wiki/Oxigenoterapia" title="Oxigenoterapia">
#                 oxigénio
#                </a>
#                e 5% são infeções muito graves que necessitam de
#                <a href="/wiki/Ventila%C3%A7%C3%A3o_mec%C3%A2nica" title="Ventilação mecânica">
#                 ventilação
#                </a>
#                . Os casos mais graves podem evoluir para
#                <a href="/wiki/Pneumonia" title="Pneumonia">
#                 pneumonia
#                </a>
#                grave com
#                <a href="/wiki/Insufici%C3%AAncia_respirat%C3%B3ria" title="Insuficiência respiratória">
#                 insuficiência respiratória aguda
#                </a>
#                ,
#                <a href="/wiki/S%C3%ADndrome_da_disfun%C3%A7%C3%A3o_de_m%C3%BAltiplos_%C3%B3rg%C3%A3os" title="Síndrome da disfunção de múltiplos órgãos">
#                 falência de vários órgãos
#                </a>
#                e
#                <a href="/wiki/Morte" title="Morte">
#                 morte
#                </a>
#                .
#               </p>
#               <p>
#                A doença transmite-se através de gotículas produzidas nas
#                <a href="/wiki/Trato_respirat%C3%B3rio" title="Trato respiratório">
#                 vias respiratórias
#                </a>
#                das pessoas infetadas. Ao espirrar ou tossir, essas gotículas podem ser inaladas ou atingir diretamente a boca, nariz ou olhos de pessoas em contacto próximo. Essas gotículas podem também depositar-se em objetos e superfícies próximos que podem infetar quem nelas toque e leve a mão aos olhos, nariz ou boca, embora esta forma de transmissão seja menos comum. O intervalo de tempo entre a exposição ao vírus e o início dos sintomas é de 2 a 14 dias, sendo em média 5 dias.
#               </p>
#               <p>
#                Entre os
#                <a class="mw-redirect" href="/wiki/Fatores_de_risco" title="Fatores de risco">
#                 fatores de risco
#                </a>
#                estão a idade avançada e doenças crónicas graves como
#                <a class="mw-redirect" href="/wiki/Doen%C3%A7as_cardiovasculares" title="Doenças cardiovasculares">
#                 doenças cardiovasculares
#                </a>
#                ,
#                <a class="mw-redirect" href="/wiki/Diabetes" title="Diabetes">
#                 diabetes
#                </a>
#                ou
#                <a href="/wiki/Doen%C3%A7a_respirat%C3%B3ria" title="Doença respiratória">
#                 doenças pulmonares
#                </a>
#                . O diagnóstico é suspeito com base nos sintomas e fatores de risco e confirmado com ensaios em tempo real de
#                <a href="/wiki/RT-PCR" title="RT-PCR">
#                 reação em cadeia de polimerase
#                </a>
#                para deteção de
#                <a class="mw-redirect" href="/wiki/ARN" title="ARN">
#                 ARN
#                </a>
#                do vírus em amostras de muco ou de sangue.
#                <b>
#                 <a href="/wiki/COVID-19" title="COVID-19">
#                  Leia mais...
#                 </a>
#                </b>
#               </p>
#              </td>
#             </tr>
#             <tr>
#              <td style="text-align:center">
#               <span class="noprint plainlinks purgelink">
#                <a class="external text" href="https://pt.wikipedia.org/w/index.php?title=Portal:COVID-19&amp;action=purge">
#                 <span title="Recarregar esta página">
#                  <b>
#                   Mostrar novas seleções abaixo
#                   <i>
#                    (purgar)
#                   </i>
#                  </b>
#                 </span>
#                </a>
#               </span>
#              </td>
#             </tr>
#            </tbody>
#           </table>
#           <table style="width:100%;background:#ECF0FC">
#            <tbody>
#             <tr>
#              <td style="border-bottom:none;padding:0.5em;width:56%; background:#4169E1;">
#               <span style="font-weight:bold; font-size:100%;color:#FFFFFF;">
#                <div style="text-align:center;">
#                 <i>
#                  Artigo em destaque
#                 </i>
#                </div>
#               </span>
#              </td>
#              <td style="border-bottom:none;padding:0.5em;width:44%; background:#4169E1;">
#               <span style="font-weight:bold; font-size:100%;color:#FFFFFF;">
#                <div style="text-align:center;">
#                 <i>
#                  Progresso da doença
#                 </i>
#                </div>
#               </span>
#              </td>
#             </tr>
#             <tr>
#              <td style="padding:0.5em; vertical-align:top; background:#FFFFFF;margin-bottom:-0.5em;padding-top:0.5em; padding-left:1em">
#               <div class="thumb tright">
#                <div class="thumbinner" style="width:352px;">
#                 <a class="image" href="/wiki/Ficheiro:DowJones2020crash.png">
#                  <img alt="" class="thumbimage" data-file-height="591" data-file-width="1193" decoding="async" height="173" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/64/DowJones2020crash.png/350px-DowJones2020crash.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/64/DowJones2020crash.png/525px-DowJones2020crash.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/64/DowJones2020crash.png/700px-DowJones2020crash.png 2x" width="350"/>
#                 </a>
#                 <div class="thumbcaption">
#                  <div class="magnify">
#                   <a class="internal" href="/wiki/Ficheiro:DowJones2020crash.png" title="Ampliar">
#                   </a>
#                  </div>
#                  Movimento do
#                  <a href="/wiki/Dow_Jones_Industrial_Average" title="Dow Jones Industrial Average">
#                   Dow Jones
#                  </a>
#                  entre dezembro de 2019 e março de 2020, mostrando a maior alta histórica de fevereiro e o
#                  <i>
#                   crash
#                  </i>
#                  de fevereiro e março durante a
#                  <a href="/wiki/Pandemia_de_COVID-19" title="Pandemia de COVID-19">
#                   pandemia de COVID-19
#                  </a>
#                  .
#                 </div>
#                </div>
#               </div>
#               <p>
#                A
#                <b>
#                 <a href="/wiki/Queda_do_mercado_de_a%C3%A7%C3%B5es_em_2020" title="Queda do mercado de ações em 2020">
#                  queda do mercado de ações em 2020
#                 </a>
#                </b>
#                refere-se a um colapso global contínuo do
#                <a href="/wiki/Crash_(economia)" title="Crash (economia)">
#                 mercado de ações,
#                </a>
#                iniciado no final de fevereiro de 2020. A
#                <a href="/wiki/Dow_Jones_Industrial_Average" title="Dow Jones Industrial Average">
#                 Dow Jones Industrial Average
#                </a>
#                , o
#                <a href="/wiki/S%26P_500" title="S&amp;P 500">
#                 Índice S&amp;P 500
#                </a>
#                e o
#                <a href="/wiki/NASDAQ-100" title="NASDAQ-100">
#                 NASDAQ-100
#                </a>
#                caíram em uma
#                <a href="/wiki/Tend%C3%AAncias_de_mercado" title="Tendências de mercado">
#                 correção
#                </a>
#                em 27 de fevereiro, durante uma das piores semanas de negociação desde a
#                <a href="/wiki/Crise_financeira_de_2007%E2%80%932008" title="Crise financeira de 2007–2008">
#                 crise financeira de 2007-2008
#                </a>
#                . Os mercados da semana seguinte (2 a 6 de março) tornaram-se extremamente voláteis, com oscilações de 3% ou mais por sessão diária (exceto em 6 de março). Em 9 de março, os estoques globais caíram mais de 7%, principalmente em resposta à guerra de preços de petróleo entre a
#                <a href="/wiki/R%C3%BAssia" title="Rússia">
#                 Rússia
#                </a>
#                e a
#                <a href="/wiki/Ar%C3%A1bia_Saudita" title="Arábia Saudita">
#                 Arábia Saudita
#                </a>
#                . Esse acontecimento ficou conhecido coloquialmente como "segunda-feira negra" e foi a pior queda desde o início da
#                <a href="/wiki/Grande_Recess%C3%A3o" title="Grande Recessão">
#                 Grande Recessão
#                </a>
#                , em 2008. Depois houve a "quinta-feira negra", dia em que as ações na Europa e na América do Norte caíram mais de 9%. Wall Street teve sua maior queda percentual em um dia desde a
#                <a class="mw-redirect" href="/wiki/Segunda-feira_negra" title="Segunda-feira negra">
#                 segunda-feira negra de 1987
#                </a>
#                e o FTSE MIB caiu quase 17%, tornando-se o mercado mais atingido na quinta-feira Negra.
#               </p>
#               <p>
#                A queda repentina no final de fevereiro foi atribuída ao medo de que a
#                <a href="/wiki/China" title="China">
#                 China
#                </a>
#                pudesse produzir um choque econômico global, principalmente devido às quarentenas impostas pelo Estado para combater a
#                <a href="/wiki/Pandemia_de_COVID-19" title="Pandemia de COVID-19">
#                 pandemia
#                </a>
#                do
#                <a href="/wiki/Pandemia_de_COVID-19" title="Pandemia de COVID-19">
#                 COVID-19
#                </a>
#                , que na época era classificada como epidemia. Relatórios sobre os vírus disseminados na
#                <a class="mw-redirect" href="/wiki/Surto_de_COVID-19_na_Coreia_do_Sul" title="Surto de COVID-19 na Coreia do Sul">
#                 Coreia do Sul
#                </a>
#                ,
#                <a class="mw-redirect" href="/wiki/Surto_de_COVID-19_na_It%C3%A1lia" title="Surto de COVID-19 na Itália">
#                 Itália
#                </a>
#                e
#                <a class="mw-redirect" href="/wiki/Surto_de_COVID-19_no_Ir%C3%A3" title="Surto de COVID-19 no Irã">
#                 Irã
#                </a>
#                também provocaram medo nos investidores, chegando a uma liquidação maciça nos mercados de ações da Ásia-Pacífico e também nos europeus.
#                <b>
#                 <a href="/wiki/Queda_do_mercado_de_a%C3%A7%C3%B5es_em_2020" title="Queda do mercado de ações em 2020">
#                  Leia mais...
#                 </a>
#                </b>
#               </p>
#              </td>
#              <td style="padding:0.5em; vertical-align:top; background:#FFFFFF;margin-bottom:-0.5em;padding-top:0.5em; padding-left:1em">
#               <p>
#                <small>
#                 <i>
#                  O trecho seguinte está compactado para despoluir visualmente a página.
#                 </i>
#                </small>
#               </p>
#               <div style="clear:both;">
#               </div>
#               <p>
#                <span style="font-size: 120%;">
#                </span>
#                <style data-mw-deduplicate="TemplateStyles:r58041413">
# ...
#              !CS1 ucraniano-fontes em língua (uk)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_checo-fontes_em_l%C3%ADngua_(cs)" title="Categoria:!CS1 checo-fontes em língua (cs)">
#              !CS1 checo-fontes em língua (cs)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_neerland%C3%AAs-fontes_em_l%C3%ADngua_(nl)" title="Categoria:!CS1 neerlandês-fontes em língua (nl)">
#              !CS1 neerlandês-fontes em língua (nl)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!P%C3%A1ginas_com_cita%C3%A7%C3%B5es_usando_par%C3%A2metros_sem_suporte" title="Categoria:!Páginas com citações usando parâmetros sem suporte">
#              !Páginas com citações usando parâmetros sem suporte
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!P%C3%A1ginas_com_erros_CS1:_t%C3%ADtulo_traduzido" title="Categoria:!Páginas com erros CS1: título traduzido">
#              !Páginas com erros CS1: título traduzido
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_manut:_Falta_pipe" title="Categoria:!CS1 manut: Falta pipe">
#              !CS1 manut: Falta pipe
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_%C3%A1rabe-fontes_em_l%C3%ADngua_(ar)" title="Categoria:!CS1 árabe-fontes em língua (ar)">
#              !CS1 árabe-fontes em língua (ar)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_romeno-fontes_em_l%C3%ADngua_(ro)" title="Categoria:!CS1 romeno-fontes em língua (ro)">
#              !CS1 romeno-fontes em língua (ro)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_sueco-fontes_em_l%C3%ADngua_(sv)" title="Categoria:!CS1 sueco-fontes em língua (sv)">
#              !CS1 sueco-fontes em língua (sv)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_usa_script_na_l%C3%ADngua_hebraico_(he)" title="Categoria:!CS1 usa script na língua hebraico (he)">
#              !CS1 usa script na língua hebraico (he)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_hebraico-fontes_em_l%C3%ADngua_(he)" title="Categoria:!CS1 hebraico-fontes em língua (he)">
#              !CS1 hebraico-fontes em língua (he)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_usa_script_na_l%C3%ADngua_bengal%C3%AAs_(bn)" title="Categoria:!CS1 usa script na língua bengalês (bn)">
#              !CS1 usa script na língua bengalês (bn)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_bengal%C3%AAs-fontes_em_l%C3%ADngua_(bn)" title="Categoria:!CS1 bengalês-fontes em língua (bn)">
#              !CS1 bengalês-fontes em língua (bn)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_usa_script_na_l%C3%ADngua_japon%C3%AAs_(ja)" title="Categoria:!CS1 usa script na língua japonês (ja)">
#              !CS1 usa script na língua japonês (ja)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_japon%C3%AAs-fontes_em_l%C3%ADngua_(ja)" title="Categoria:!CS1 japonês-fontes em língua (ja)">
#              !CS1 japonês-fontes em língua (ja)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_malaio-fontes_em_l%C3%ADngua_(ms)" title="Categoria:!CS1 malaio-fontes em língua (ms)">
#              !CS1 malaio-fontes em língua (ms)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_usa_script_na_l%C3%ADngua_%C3%A1rabe_(ar)" title="Categoria:!CS1 usa script na língua árabe (ar)">
#              !CS1 usa script na língua árabe (ar)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_usa_script_na_l%C3%ADngua_b%C3%BAlgaro_(bg)" title="Categoria:!CS1 usa script na língua búlgaro (bg)">
#              !CS1 usa script na língua búlgaro (bg)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_b%C3%BAlgaro-fontes_em_l%C3%ADngua_(bg)" title="Categoria:!CS1 búlgaro-fontes em língua (bg)">
#              !CS1 búlgaro-fontes em língua (bg)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_usa_script_na_l%C3%ADngua_grego_(el)" title="Categoria:!CS1 usa script na língua grego (el)">
#              !CS1 usa script na língua grego (el)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_grego-fontes_em_l%C3%ADngua_(el)" title="Categoria:!CS1 grego-fontes em língua (el)">
#              !CS1 grego-fontes em língua (el)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_cazaque-fontes_em_l%C3%ADngua_(kk)" title="Categoria:!CS1 cazaque-fontes em língua (kk)">
#              !CS1 cazaque-fontes em língua (kk)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_azerbaijano-fontes_em_l%C3%ADngua_(az)" title="Categoria:!CS1 azerbaijano-fontes em língua (az)">
#              !CS1 azerbaijano-fontes em língua (az)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_dinamarqu%C3%AAs-fontes_em_l%C3%ADngua_(da)" title="Categoria:!CS1 dinamarquês-fontes em língua (da)">
#              !CS1 dinamarquês-fontes em língua (da)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_lituano-fontes_em_l%C3%ADngua_(lt)" title="Categoria:!CS1 lituano-fontes em língua (lt)">
#              !CS1 lituano-fontes em língua (lt)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_am%C3%A1rico-fontes_em_l%C3%ADngua_(am)" title="Categoria:!CS1 amárico-fontes em língua (am)">
#              !CS1 amárico-fontes em língua (am)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_esloveno-fontes_em_l%C3%ADngua_(sl)" title="Categoria:!CS1 esloveno-fontes em língua (sl)">
#              !CS1 esloveno-fontes em língua (sl)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_usa_script_na_l%C3%ADngua_arm%C3%A9nio_(hy)" title="Categoria:!CS1 usa script na língua arménio (hy)">
#              !CS1 usa script na língua arménio (hy)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_arm%C3%A9nio-fontes_em_l%C3%ADngua_(hy)" title="Categoria:!CS1 arménio-fontes em língua (hy)">
#              !CS1 arménio-fontes em língua (hy)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_maced%C3%B3nio-fontes_em_l%C3%ADngua_(mk)" title="Categoria:!CS1 macedónio-fontes em língua (mk)">
#              !CS1 macedónio-fontes em língua (mk)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_usa_script_na_l%C3%ADngua_tailand%C3%AAs_(th)" title="Categoria:!CS1 usa script na língua tailandês (th)">
#              !CS1 usa script na língua tailandês (th)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_tailand%C3%AAs-fontes_em_l%C3%ADngua_(th)" title="Categoria:!CS1 tailandês-fontes em língua (th)">
#              !CS1 tailandês-fontes em língua (th)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_alban%C3%AAs-fontes_em_l%C3%ADngua_(sq)" title="Categoria:!CS1 albanês-fontes em língua (sq)">
#              !CS1 albanês-fontes em língua (sq)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_let%C3%A3o-fontes_em_l%C3%ADngua_(lv)" title="Categoria:!CS1 letão-fontes em língua (lv)">
#              !CS1 letão-fontes em língua (lv)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_fontes_em_l%C3%ADngua_estrangeira_(ISO_639-2)" title="Categoria:!CS1 fontes em língua estrangeira (ISO 639-2)">
#              !CS1 fontes em língua estrangeira (ISO 639-2)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_usa_script_na_l%C3%ADngua_chin%C3%AAs_(zh)" title="Categoria:!CS1 usa script na língua chinês (zh)">
#              !CS1 usa script na língua chinês (zh)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_chin%C3%AAs-fontes_em_l%C3%ADngua_(zh)" title="Categoria:!CS1 chinês-fontes em língua (zh)">
#              !CS1 chinês-fontes em língua (zh)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_ingl%C3%AAs-fontes_em_l%C3%ADngua_(en)" title="Categoria:!CS1 inglês-fontes em língua (en)">
#              !CS1 inglês-fontes em língua (en)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_khmer-fontes_em_l%C3%ADngua_(km)" title="Categoria:!CS1 khmer-fontes em língua (km)">
#              !CS1 khmer-fontes em língua (km)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_catal%C3%A3o-fontes_em_l%C3%ADngua_(ca)" title="Categoria:!CS1 catalão-fontes em língua (ca)">
#              !CS1 catalão-fontes em língua (ca)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_turco-fontes_em_l%C3%ADngua_(tr)" title="Categoria:!CS1 turco-fontes em língua (tr)">
#              !CS1 turco-fontes em língua (tr)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_island%C3%AAs-fontes_em_l%C3%ADngua_(is)" title="Categoria:!CS1 islandês-fontes em língua (is)">
#              !CS1 islandês-fontes em língua (is)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_vietnamita-fontes_em_l%C3%ADngua_(vi)" title="Categoria:!CS1 vietnamita-fontes em língua (vi)">
#              !CS1 vietnamita-fontes em língua (vi)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_somali-fontes_em_l%C3%ADngua_(so)" title="Categoria:!CS1 somali-fontes em língua (so)">
#              !CS1 somali-fontes em língua (so)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!CS1_laosiano-fontes_em_l%C3%ADngua_(lo)" title="Categoria:!CS1 laosiano-fontes em língua (lo)">
#              !CS1 laosiano-fontes em língua (lo)
#             </a>
#            </li>
#            <li>
#             <a href="/wiki/Categoria:!Portais_destacados" title="Categoria:!Portais destacados">
#              !Portais destacados
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </main>
#       <div id="mw-data-after-content">
#        <div class="read-more-container">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="mw-workspace-container mw-footer-container">
#      <div class="mw-content-container">
#       <footer class="mw-footer" id="footer" role="contentinfo">
#        <ul id="footer-info">
#         <li id="footer-info-lastmod">
#          Esta página foi editada pela última vez às 19h44min de 20 de abril de 2020.
#         </li>
#         <li id="footer-info-copyright">
#          Este texto é disponibilizado nos termos da licença
#          <a href="https://creativecommons.org/licenses/by-sa/3.0/deed.pt">
#           Atribuição-CompartilhaIgual 3.0 Não Adaptada (CC BY-SA 3.0) da Creative Commons
#          </a>
#          ;
# pode estar sujeito a condições adicionais.
# Para mais detalhes, consulte as
#          <a href="https://foundation.wikimedia.org/wiki/Condições_de_Uso">
#           condições de utilização
#          </a>
#          .
#         </li>
#        </ul>
#        <ul id="footer-places">
#         <li id="footer-places-privacy">
#          <a class="extiw" href="https://meta.wikimedia.org/wiki/Privacy_policy/pt-br" title="m:Privacy policy/pt-br">
#           Política de privacidade
#          </a>
#         </li>
#         <li id="footer-places-about">
#          <a class="mw-redirect" href="/wiki/Wikip%C3%A9dia:Sobre" title="Wikipédia:Sobre">
#           Sobre a Wikipédia
#          </a>
#         </li>
#         <li id="footer-places-disclaimer">
#          <a href="/wiki/Wikip%C3%A9dia:Aviso_geral" title="Wikipédia:Aviso geral">
#           Avisos gerais
#          </a>
#         </li>
#         <li id="footer-places-mobileview">
#          <a class="noprint stopMobileRedirectToggle" href="//pt.m.wikipedia.org/w/index.php?title=Portal:COVID-19&amp;mobileaction=toggle_view_mobile">
#           Versão móvel
#          </a>
#         </li>
#         <li id="footer-places-developers">
#          <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#           Programadores
#          </a>
#         </li>
#         <li id="footer-places-statslink">
#          <a href="https://stats.wikimedia.org/#/pt.wikipedia.org">
#           Estatísticas
#          </a>
#         </li>
#         <li id="footer-places-cookiestatement">
#          <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#           Declaração sobre ''cookies''
#          </a>
#         </li>
#        </ul>
#        <ul class="noprint" id="footer-icons">
#         <li id="footer-copyrightico">
#          <a href="https://wikimediafoundation.org/">
#           <img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/>
#          </a>
#         </li>
#         <li id="footer-poweredbyico">
#          <a href="https://www.mediawiki.org/">
#           <img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/>
#          </a>
#         </li>
#        </ul>
#       </footer>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"2.850","walltime":"3.296","ppvisitednodes":{"value":14338,"limit":1000000},"postexpandincludesize":{"value":606605,"limit":2097152},"templateargumentsize":{"value":57094,"limit":2097152},"expansiondepth":{"value":19,"limit":40},"expensivefunctioncount":{"value":22,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":327677,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00% 2130.581      1 -total"," 47.45% 1010.872    265 Predefinição:Cite_web"," 32.97%  702.478      7 Portal:COVID-19/Conteúdo"," 28.87%  615.135      1 Portal:COVID-19/Progresso"," 28.47%  606.573      1 Predefinição:Dados_da_pandemia_de_COVID-19","  4.49%   95.564     11 Predefinição:Cite_tweet","  3.36%   71.584     12 Predefinição:Citar_web","  2.71%   57.797     13 Predefinição:Cite_news","  2.59%   55.133      1 Predefinição:Portal_destacado","  2.46%   52.332     18 Predefinição:Contar_páginas/núcleo"]},"scribunto":{"limitreport-timeusage":{"value":"1.100","limit":"10.000"},"limitreport-memusage":{"value":6098103,"limit":52428800},"limitreport-profile":[["recursiveClone \u003CmwInit.lua:41\u003E","260","25.5"],["?","260","25.5"],["init \u003CMódulo:Citação/CS1/Configuração\u003E","60","5.9"],["Scribunto_LuaSandboxCallback::plain","40","3.9"],["Scribunto_LuaSandboxCallback::match","40","3.9"],["Scribunto_LuaSandboxCallback::fetchLanguageName","40","3.9"],["match","20","2.0"],["select_one \u003CMódulo:Citação/CS1/Utilidades:228\u003E","20","2.0"],["[main chunk] \u003Cpackage.lua\u003E","20","2.0"],["gsub","20","2.0"],["[others]","240","23.5"]]},"cachereport":{"origin":"mw1274","timestamp":"20210606180519","ttl":1814400,"transientcontent":false}}});mw.config.set({"wgBackendResponseTime":126,"wgHostname":"mw1403"});});
#   </script>
#  </body>
# </html>

# %% [markdown]
# **Inspeção da página**

# %% [markdown]
# Inspecionando o código-fonte da página HTML no navegador (Chrome, Firefox etc) podemos ver que a tabela de interesse contém a classe CSS: `wikitable sortable mw-collapsible no-ref`. Vamos utilizar esta classe CSS para restringir a busca pelos elementos de interesse.

# %%
tb_covid_pais = soup.find(class_='wikitable sortable mw-collapsible no-ref')
#tb_covid_pais

# %% [markdown]
# Opcionalmente, pode-se fazer o seguinte.

# %%
tbs_covid_pais = soup.find_all(class_='wikitable sortable mw-collapsible no-ref')
# Lembre-se que o método find_all retorna uma lista. No caso deste exemplo, 
# só existe um elemento na lista
tb_covid_pais = tbs_covid_pais[0]
# tb_covid_pais

# %%
# Retorna uma lista com todas as linhas da tabela
linhas_tb = tb_covid_pais.find_all('tr')
#linhas_tb

# %% [markdown]
# > **Atenção**: É sempre importante entender o tipo de uma variável.

# %%
type(linhas_tb)
# Out:
# bs4.element.ResultSet

# %%
type(linhas_tb[0])
# Out:
# bs4.element.Tag

# %% [markdown]
# **Investigando os resultados**

# %% [markdown]
# Primeiro país ocorre na posição 2.

# %%
linhas_tb[2].get_text()
# Out:
# '\n Estados Unidos[a]\n33\xa0503\xa0141\n\n602\xa0805\n\n–\n\n[2]\n'

# %% [markdown]
# Último ocorre na posição 226.

# %%
linhas_tb[226].get_text()
# Out:
# '\n Saba\n7\n\n0\n\n7\n\n[291]\n'

# %%
ini_tb = 2
fim_tb = 226

# %% [markdown]
# Brincando um pouco com esses objetos podemos ver que eles contém os dados que desejamos. No entanto, esses dados precisem ser tratados. Por exemplo: podemos ver que o resultado a seguir começa e termina com `\n` (caractere de nova linha); existe um espaço antes do nome do país; existem vários `\n` e `\xa0` (*line feed*) no meio da linha. Além disso, existem notas associadas ao nome do país e ao final da linha. Vamos cuidar de cada um desses problemas.

# %%
lin = linhas_tb[2].get_text()
lin
# Out:
# '\n Estados Unidos[a]\n33\xa0503\xa0141\n\n602\xa0805\n\n–\n\n[2]\n'

# %% [markdown]
# ##### Removendo os `\n` e os espaços no começo e ao final da linha.

# %% [markdown]
# O método `strip()` remove caracteres no começo e ao final da linha.

# %%
lin
# Out:
# '\n Estados Unidos[a]\n33\xa0503\xa0141\n\n602\xa0805\n\n–\n\n[2]\n'

# %%
lin.strip("\n \t")
# Out:
# 'Estados Unidos[a]\n33\xa0503\xa0141\n\n602\xa0805\n\n–\n\n[2]'

# %% [markdown]
# Note que a variável `lin` não é alterada desta forma.

# %%
lin
# Out:
# '\n Estados Unidos[a]\n33\xa0503\xa0141\n\n602\xa0805\n\n–\n\n[2]\n'

# %% [markdown]
# Para que a variável `lin` seja alterada, é necessário utilizar a atribuição.

# %%
lin = lin.strip("\n ")
lin
# Out:
# 'Estados Unidos[a]\n33\xa0503\xa0141\n\n602\xa0805\n\n–\n\n[2]'

# %% [markdown]
# ##### Removendo os caracteres `\xa0` e `\n` no meio da string

# %% [markdown]
# Podemos utilizar o método `replace()` para substituir o caractere `\xa0` com a string vazia, para que o número de casos não esteja com espaços entre eles. Note que o caractere `\xa0` está em Unicode (que podem ser representados por hexadecimais), por isso necessitam do `u` antes do começo da string.

# %%
lin = lin.replace(u"\xa0", u"")
lin
# Out:
# 'Estados Unidos[a]\n33503141\n\n602805\n\n–\n\n[2]'

# %% [markdown]
# Como desejamos criar um arquivo CSV ao final do processo, vamos substituir um ou mais `\n` e `\t` que separa cada coluna da tabela por um `\t`.

# %%
lin = re.sub("[\n|\t]+","\t", lin)
lin
# Out:
# 'Estados Unidos[a]\t33503141\t602805\t–\t[2]'

# %% [markdown]
# ##### Removendo as notas do nome do país e ao final da linha

# %% [markdown]
# Para remover as notas do nome do país, vamos utilizar a seguinte expressão regular: `r"\[[\d|a-z]+\]"`. A expressão pode ser lida da seguinte forma: selecione o texto de dígitos ou caracteres alfa-numéricos que estejam entre `[` e `]`.

# %%
lin
# Out:
# 'Estados Unidos[a]\t33503141\t602805\t–\t[2]'

# %%
lin = re.sub(r"\[[\d|a-z]+\]", "", lin)
lin
# Out:
# 'Estados Unidos\t33503141\t602805\t–\t'

# %% [markdown]
# Remove-se finalmente o `\t` ao final da string.

# %%
# Coluna Fontes
lin = lin.rstrip("\t")
lin
# Out:
# 'Estados Unidos\t33503141\t602805\t–'

# %%
lin = lin.replace("–", "0")
lin
# Out:
# 'Estados Unidos\t33503141\t602805\t0'

# %% [markdown]
# ### Criação de uma função de preparação da linha

# %% [markdown]
# Para se criar a função, vamos começar aplicando a sequência de passos para preparar a linha dos EUA e em seguida analisar se o que fizemos é suficiente para os outros casos.

# %%
def prep_linha_v1(linha):
    # Remove os caracteres \n no começo e final da string
    # Em seguida, remove os espaços
    linha = linha.strip("\n ")
    linha = linha.replace(u"\xa0", u"")
    linha = re.sub("[\n|\t]+","\t", linha)
    linha = re.sub(r"\[[\d|a-z]+\]", "", linha)
    linha = linha.strip("\t")
    linha = re.sub(r"–", "0", linha)
    return linha

# %% [markdown]
# Como esperado, a função funciona para os EUA.

# %%
eua = prep_linha_v1(linhas_tb[2].get_text())
eua
# Out:
# 'Estados Unidos\t33503141\t602805\t0'

# %% [markdown]
# #### Preste atenção nos tipos de dados da entrada das funções.

# %% [markdown]
# Chamada com String.

# %%
type(linhas_tb[2].get_text())
# Out:
# str

# %%
prep_linha_v1(linhas_tb[2].get_text())
# Out:
# 'Estados Unidos\t33503141\t602805\t0'

# %% [markdown]
# Chamada com `Tag`

# %%
type(linhas_tb[2])
# Out:
# bs4.element.Tag

# %%
#prep_linha_v1(linhas_tb[2])

# %% [markdown]
# #### Investigando outros casos

# %% [markdown]
# Listando as transformações nos países.

# %%
for i in range(ini_tb,fim_tb+1):
    linha = linhas_tb[i].get_text()
    print(i, prep_linha_v1(linha))
# Out:
# 2 Estados Unidos	33503141	602805	0
# 3 Índia	26752447	303720	23728011
# 4 Brasil	16907425	472531	15290500
# 5 França	5707683	110002	0
# 6 Turquia	5287980	48164	5160774
# 7 Rússia	5126437	123787	4736446
# 8 Reino Unido	4516892	127840	0
# 9 Itália	4230153	126472	3908312
# 10 Argentina	3938961	80867	3497437
# 11 Espanha	3697987	80196	0
# 12 Alemanha	3717890	89825	3533648
# 13 Colômbia	3518046	90890	3267100
# 14 Irã	2954309	80813	2522702
# 15 Polônia	2875136	74152	2645150
# 16 México	2432280	228754	1937977
# 17 Ucrânia	2214517	51182	2093228
# 18 Peru	1980391	186073	1931773
# 19 Chéquia	1663517	30159	1624721
# 20 África do Sul	1691491	56929	1574223
# 21 Países Baixos	1661520	17675	0
# 22 Indonésia	1 511 712	40 858	1 348 330
# 23 Canadá	1391174	25712	1340123
# 24 Chile	1427956	29937	1347676
# 25 Filipinas	1269478	21898	1188243
# 26 Iraque	1218524	16488	1133347
# 27 Romênia	1078863	30815	1042898
# 28 Suécia	1078062	14523	0
# 29 Bélgica	1069874	25019	0
# 30 Paquistão	932140	21265	863111
# 31 Portugal	852646	17034	811897
# 32 Israel	839539	6417	832923
# 33 Hungria	805871	29842	714329
# 34 Bangladesh	809314	12801	749425
# 35 Jordânia	739015	9509	719676
# 36 Japão	760323	13523	703525
# 37 Sérvia	713678	6917	0
# 38 Suíça	697292	10272	317600
# 39 Áustria	646800	10639	630942
# 40 Emirados Árabes Unidos	583071	1699	562576
# 41 Nepal	588124	7898	491009
# 42 Malásia	616815	3378	526809
# 43 Líbano	541423	7758	523476
# 44 Marrocos	521195	9173	508850
# 45 Arábia Saudita	456562	7440	439459
# 46 Equador	432325	20773	398645
# 47 Bulgária	419426	17813	386068
# 48 Grécia	407857	12218	data-sort-value="−1"
# 49 Bielorrússia	399852	2910	392366
# 50 Eslováquia	390436	12404	0
# 51 Cazaquistão	394075	4042	366204
# 52 Panamá	381949	6395	367991
# 53 Bolívia	385734	14981	305219
# 54 Croácia	357565	8086	347997
# 55 Paraguai	371021	9739	304294
# 56 Geórgia	349098	4910	333505
# 57 Tunísia	352303	12902	309126
# 58 Azerbaijão	334647	4936	326619
# 59 Costa Rica	327979	4153	247905
# 60 Palestina	309853	3516	301670
# 61 Kuwait	315900	1794	299795
# 62 República Dominicana	299681	3652	244244
# 63 Uruguai	312703	4583	271481
# 64 Dinamarca	286489	2518	271568
# 65 Lituânia	276453	4307	259793
# 66 Etiópia	272805	4201	245648
# 67 Irlanda	263720	4941	0
# 68 Egito	267171	15309	195871
# 69 Moldávia	255432	6132	248013
# 70 Eslovênia	255218	4387	0
# 71 Guatemala	261958	8294	239176
# 72 Honduras	241574	6460	86046
# 73 Venezuela	240714	2708	221108
# 74 Bahrain	249582	1091	225159
# 75 Armênia	223180	4458	214363
# 76 Qatar	218627	569	215294
# 77 Omã	220702	2385	202021
# 78 Bósnia e Herzegovina	204304	9374	176286
# 79 Líbia	186953	3137	172916
# 80 Sri Lanka	204278	1696	167304
# 81 Quênia	172491	3287	117595
# 82 Nigéria	166756	2117	162994
# 83 Macedônia do Norte	155407	5448	148960
# 84 Tailândia	177467	1236	126517
# 85 Myanmar	144317	3225	132452
# 86 Coreia do Sul	144152	1973	134262
# 87 Cuba	147831	1003	140809
# 88 Albânia	132379	2451	129664
# 89 Letônia	134812	2412	128619
# 90 Estônia	130119	1263	124659
# 91 Argélia	130681	3510	90995
# 92 Noruega	126773	785	88952
# 93 Porto Rico	122254	2518	0
# 94 Kosovo	107417	2241	103711
# 95 Quirguistão	106636	1842	100114
# 96 Montenegro	99812	1592	97578
# 97 Uzbequistão	101198	695	97077
# 98 Zâmbia	100278	1308	93374
# 99 Gana	94188	786	92309
# 100 Finlândia	93226	959	31000
# 101 China (continental)	91248	4636	86220
# 102 Camarões	78929	1275	57008
# 103 El Salvador	74141	2260	69215
# 104 Chipre	72750	363	0
# 105 Moçambique	71082	837	69656
# 106 Luxemburgo	70182	818	68556
# 107 Afeganistão	79236	3145	58265
# 108 Singapura	62176	33	61613
# 109 Maldivas	67538	182	46334
# 110 Mongólia	65266	312	53780
# 111 Namíbia	58057	905	51882
# 112 Botswana	54973	849	51259
# 113 Jamaica	48901	964	26102
# 114 Costa do Marfim	47476	306	46941
# 115 Uganda	51006	374	47760
# 116 Senegal	41581	1144	40201
# 117 Madagáscar	41631	859	40676
# 118 Zimbábue	39168	1605	36698
# 119 Donetsk	39963	3034	32089
# 120 Sudão	35656	2662	29364
# 121 Malawi	34390	1157	32667
# 122 Angola	35594	794	28866
# 123 Rep. Dem. do Congo	33201	804	27751
# 124 Malta	30571	419	30078
# 125 Austrália	30175	910	0
# 126 Cabo Verde	31003	267	29432
# 127 Camboja	34244	263	27147
# 128 Ruanda	27211	359	26171
# 129 Síria	24639	1790	21630
# 130 Gabão	24591	154	22815
# 131 Guiné	23255	162	21284
# 132 Trinidad e Tobago	26192	554	15564
# 133 Mauritânia	19785	466	18759
# 134 Polinésia Francesa	18889	142	18658
# 135 Essuatíni	18636	673	17896
# 136 Guiana	17617	405	15350
# 137 Papua-Nova Guiné	16327	164	15641
# 138 Abecásia	15360	234	14737
# 139 Somália	14660	769	6764
# 140 Mali	14296	518	9844
# 141 Haiti	15295	323	12552
# 142 Suriname	16292	339	12365
# 143 Tajiquistão	13714	91	13218
# 144 Andorra	13758	127	13534
# 145 Burkina Faso	13452	167	13265
# 146 Togo	13533	125	13248
# 147 Belize	12861	325	12439
# 148 Curaçao	12278	123	12137
# 149 Hong Kong	11859	210	11561
# 150 República do Congo	11920	155	8208
# 151 Bahamas	11930	232	10932
# 152 Djibouti	11562	154	11385
# 153 Seicheles	12158	42	10883
# 154 Aruba	11041	107	10878
# 155 Lesoto	10837	326	6437
# 156 Sudão do Sul	10688	115	10514
# 157 Guiné Equatorial	8626	118	8203
# 158 Guam	8204	139	8000
# 159 Benim	8025	101	7893
# 160 Nicarágua	7481	187	0
# 161 Chipre do Norte	7409	33	7082
# 162 República Centro-Africana	7091	98	5112
# 163 Taiwan	11298	260	1133
# 164 Iémen	6787	1329	3571
# 165 Islândia	6604	30	6527
# 166 Vietnã	8682	53	3310
# 167 Gâmbia	5995	179	5786
# 168 Timor-Leste	6897	16	4233
# 169 Níger	5438	192	5131
# 170 San Marino	5090	90	4998
# 171 Santa Lúcia	5108	80	4876
# 172 Chade	4939	174	4754
# 173 Lugansk	4825	443	4256
# 174 Burundi	4905	8	773
# 175 Gibraltar	4300	94	4197
# 176 Serra Leoa	4201	79	3157
# 177 Eritreia	4427	14	3894
# 178 Barbados	4029	47	3922
# 179 Somalilândia	4608	311	3899
# 180 Comores	3888	146	3736
# 181 Guiné-Bissau	3766	68	3516
# 182 Ilhas Virgens Americanas	3465	27	3313
# 183 Ossétia do Sul	3346	60+	3198
# 184 Jersey	3243	69	3181
# 185 Liechtenstein	3022	58	2934
# 186 Artsaque	2754	31	337
# 187 Mônaco	2508	33	2467
# 188 Bermudas	2494	33	2451
# 189 Ilhas Turcas e Caicos	2420	17	2387
# 190 São Martinho (Países Baixos)	2479	29	2368
# 191 São Tomé e Príncipe	2353	37	2297
# 192 Nova Zelândia	2325	26	2282
# 193 Libéria	2250	86	2049
# 194 Laos	1957	3	1693
# 195 Ilha de Man	1598	29	1562
# 196 Bonaire	1589	17	1566
# 197 Butão	1687	1	1388
# 198 Maurícia	1458	18	1206
# 199 Antígua e Barbuda	1262	42	1214
# 200 Guernsey	823	14	808
# 201 Diamond Princess	712	14	698
# 202 Tanzânia	0	0	0
# 203 Ilhas Faroe	743	1	697
# 204 Ilhas Cayman	587	2	575
# 205 Fiji	687	4	193
# 206 Ilhas Virgens Britânicas	292	1	285
# 207 Brunei	244	3	231
# 208 Dominica	188	0	187
# 209 Ilhas Marianas Setentrionais	183	2	32
# 210 Granada	160	1	158
# 211 Costa Atlantica	148	0	148
# 212 Greg Mortimer	128	1	0
# 213 Nova Caledônia	128	0	30
# 214 Anguilla	109	0	109
# 215 São Vicente e Granadinas	98	0	81
# 216 Ilhas Malvinas	63	0	63
# 217 São Cristóvão e Neves	78	0	48
# 218 Macau	51	0	49
# 219 Gronelândia	43	0	34
# 220 Vaticano	29	0	27
# 221 Saint Pierre e Miquelon	25	0	25
# 222 Santo Eustáquio	20	0	20
# 223 Montserrat	20	1	18
# 224 MS Zaandam	13	4	0
# 225 Coral Princess	12	3	0
# 226 Saba	7	0	7

# %% [markdown]
# Pela Grécia, vemos que remos ter tratar um comando HTML em uma das colunas.

# %%
prep_linha_v1(linhas_tb[48].get_text())
# Out:
# 'Grécia\t407857\t12218\tdata-sort-value="−1"'

# %% [markdown]
# A Ossétia do Sul também necessita ser tratada.

# %%
prep_linha_v1(linhas_tb[183].get_text())
# Out:
# 'Ossétia do Sul\t3346\t60+\t3198'

# %%
def prep_linha_v2(linha):
    # Remove os caracteres \n no começo e final da string
    # Em seguida, remove os espaços
    linha = linha.strip("\n ")
    linha = linha.replace(u"\xa0", u"")
    linha = re.sub("[\n|\t]+","\t", linha)
    linha = re.sub(r"\[[\d|a-z]+\]", "", linha)
    linha = linha.strip("\t")
    linha = re.sub(r"–", "0", linha)
        
    # Trata a Grécia (parte por parte)
    linha = linha.replace("data-sort-value=\"−1\"", "0")
    
    # Trata a Ossétia do Sul
    linha = linha.replace("+", "")
    return linha

# %%
prep_linha_v2(linhas_tb[48].get_text())
# Out:
# 'Grécia\t407857\t12218\t0'

# %%
prep_linha_v2(linhas_tb[183].get_text())
# Out:
# 'Ossétia do Sul\t3346\t60\t3198'

# %% [markdown]
# Analisando a Indonésia, descobrimos mais uma surpresa.

# %%
prep_linha_v2(linhas_tb[22].get_text())
# Out:
# 'Indonésia\t1 511 712\t40 858\t1 348 330'

# %% [markdown]
# Para facilitar, vamos tratar este caso direto no Pandas.

# %% [markdown]
# ##### Preparando o texto do arquivo final

# %% [markdown]
# Para criarmos o texto arquivo CSV final, basta fazer uma concatenação de todas as linhas da tabela, incluindo um `\n` ao final da linha.

# %%
# Esta primeira linha define o título da tabela
texto_final = "País\tCasos\tMortes\tCurados\n"
for i in range(ini_tb, fim_tb+1):
    # Preste atenção no .get_text(), que transforma a chamada em string
    linha = prep_linha_v2(linhas_tb[i].get_text())
    texto_final += linha
    if (i < fim_tb):
        texto_final += "\n"
print(texto_final)
# Out:
# País	Casos	Mortes	Curados
# Estados Unidos	33503141	602805	0
# Índia	26752447	303720	23728011
# Brasil	16907425	472531	15290500
# França	5707683	110002	0
# Turquia	5287980	48164	5160774
# Rússia	5126437	123787	4736446
# Reino Unido	4516892	127840	0
# Itália	4230153	126472	3908312
# Argentina	3938961	80867	3497437
# Espanha	3697987	80196	0
# Alemanha	3717890	89825	3533648
# Colômbia	3518046	90890	3267100
# Irã	2954309	80813	2522702
# Polônia	2875136	74152	2645150
# México	2432280	228754	1937977
# Ucrânia	2214517	51182	2093228
# Peru	1980391	186073	1931773
# Chéquia	1663517	30159	1624721
# África do Sul	1691491	56929	1574223
# Países Baixos	1661520	17675	0
# Indonésia	1 511 712	40 858	1 348 330
# Canadá	1391174	25712	1340123
# Chile	1427956	29937	1347676
# Filipinas	1269478	21898	1188243
# Iraque	1218524	16488	1133347
# Romênia	1078863	30815	1042898
# Suécia	1078062	14523	0
# Bélgica	1069874	25019	0
# Paquistão	932140	21265	863111
# Portugal	852646	17034	811897
# Israel	839539	6417	832923
# Hungria	805871	29842	714329
# Bangladesh	809314	12801	749425
# Jordânia	739015	9509	719676
# Japão	760323	13523	703525
# Sérvia	713678	6917	0
# Suíça	697292	10272	317600
# Áustria	646800	10639	630942
# Emirados Árabes Unidos	583071	1699	562576
# Nepal	588124	7898	491009
# Malásia	616815	3378	526809
# Líbano	541423	7758	523476
# Marrocos	521195	9173	508850
# Arábia Saudita	456562	7440	439459
# Equador	432325	20773	398645
# Bulgária	419426	17813	386068
# Grécia	407857	12218	0
# Bielorrússia	399852	2910	392366
# Eslováquia	390436	12404	0
# Cazaquistão	394075	4042	366204
# Panamá	381949	6395	367991
# Bolívia	385734	14981	305219
# Croácia	357565	8086	347997
# Paraguai	371021	9739	304294
# Geórgia	349098	4910	333505
# Tunísia	352303	12902	309126
# Azerbaijão	334647	4936	326619
# Costa Rica	327979	4153	247905
# Palestina	309853	3516	301670
# Kuwait	315900	1794	299795
# República Dominicana	299681	3652	244244
# Uruguai	312703	4583	271481
# Dinamarca	286489	2518	271568
# Lituânia	276453	4307	259793
# Etiópia	272805	4201	245648
# Irlanda	263720	4941	0
# Egito	267171	15309	195871
# Moldávia	255432	6132	248013
# Eslovênia	255218	4387	0
# Guatemala	261958	8294	239176
# Honduras	241574	6460	86046
# Venezuela	240714	2708	221108
# Bahrain	249582	1091	225159
# Armênia	223180	4458	214363
# Qatar	218627	569	215294
# Omã	220702	2385	202021
# Bósnia e Herzegovina	204304	9374	176286
# Líbia	186953	3137	172916
# Sri Lanka	204278	1696	167304
# Quênia	172491	3287	117595
# Nigéria	166756	2117	162994
# Macedônia do Norte	155407	5448	148960
# Tailândia	177467	1236	126517
# Myanmar	144317	3225	132452
# Coreia do Sul	144152	1973	134262
# Cuba	147831	1003	140809
# Albânia	132379	2451	129664
# Letônia	134812	2412	128619
# Estônia	130119	1263	124659
# Argélia	130681	3510	90995
# Noruega	126773	785	88952
# Porto Rico	122254	2518	0
# Kosovo	107417	2241	103711
# Quirguistão	106636	1842	100114
# Montenegro	99812	1592	97578
# Uzbequistão	101198	695	97077
# Zâmbia	100278	1308	93374
# Gana	94188	786	92309
# Finlândia	93226	959	31000
# China (continental)	91248	4636	86220
# Camarões	78929	1275	57008
# El Salvador	74141	2260	69215
# Chipre	72750	363	0
# Moçambique	71082	837	69656
# Luxemburgo	70182	818	68556
# Afeganistão	79236	3145	58265
# Singapura	62176	33	61613
# Maldivas	67538	182	46334
# Mongólia	65266	312	53780
# Namíbia	58057	905	51882
# Botswana	54973	849	51259
# Jamaica	48901	964	26102
# Costa do Marfim	47476	306	46941
# Uganda	51006	374	47760
# Senegal	41581	1144	40201
# Madagáscar	41631	859	40676
# Zimbábue	39168	1605	36698
# Donetsk	39963	3034	32089
# Sudão	35656	2662	29364
# Malawi	34390	1157	32667
# Angola	35594	794	28866
# Rep. Dem. do Congo	33201	804	27751
# Malta	30571	419	30078
# Austrália	30175	910	0
# Cabo Verde	31003	267	29432
# Camboja	34244	263	27147
# Ruanda	27211	359	26171
# Síria	24639	1790	21630
# Gabão	24591	154	22815
# Guiné	23255	162	21284
# Trinidad e Tobago	26192	554	15564
# Mauritânia	19785	466	18759
# Polinésia Francesa	18889	142	18658
# Essuatíni	18636	673	17896
# Guiana	17617	405	15350
# Papua-Nova Guiné	16327	164	15641
# Abecásia	15360	234	14737
# Somália	14660	769	6764
# Mali	14296	518	9844
# Haiti	15295	323	12552
# Suriname	16292	339	12365
# Tajiquistão	13714	91	13218
# Andorra	13758	127	13534
# Burkina Faso	13452	167	13265
# Togo	13533	125	13248
# Belize	12861	325	12439
# Curaçao	12278	123	12137
# Hong Kong	11859	210	11561
# República do Congo	11920	155	8208
# Bahamas	11930	232	10932
# Djibouti	11562	154	11385
# Seicheles	12158	42	10883
# Aruba	11041	107	10878
# Lesoto	10837	326	6437
# Sudão do Sul	10688	115	10514
# Guiné Equatorial	8626	118	8203
# Guam	8204	139	8000
# Benim	8025	101	7893
# Nicarágua	7481	187	0
# Chipre do Norte	7409	33	7082
# República Centro-Africana	7091	98	5112
# Taiwan	11298	260	1133
# Iémen	6787	1329	3571
# Islândia	6604	30	6527
# Vietnã	8682	53	3310
# Gâmbia	5995	179	5786
# Timor-Leste	6897	16	4233
# Níger	5438	192	5131
# San Marino	5090	90	4998
# Santa Lúcia	5108	80	4876
# Chade	4939	174	4754
# Lugansk	4825	443	4256
# Burundi	4905	8	773
# Gibraltar	4300	94	4197
# Serra Leoa	4201	79	3157
# Eritreia	4427	14	3894
# Barbados	4029	47	3922
# Somalilândia	4608	311	3899
# Comores	3888	146	3736
# Guiné-Bissau	3766	68	3516
# Ilhas Virgens Americanas	3465	27	3313
# Ossétia do Sul	3346	60	3198
# Jersey	3243	69	3181
# Liechtenstein	3022	58	2934
# Artsaque	2754	31	337
# Mônaco	2508	33	2467
# Bermudas	2494	33	2451
# Ilhas Turcas e Caicos	2420	17	2387
# São Martinho (Países Baixos)	2479	29	2368
# São Tomé e Príncipe	2353	37	2297
# Nova Zelândia	2325	26	2282
# Libéria	2250	86	2049
# Laos	1957	3	1693
# Ilha de Man	1598	29	1562
# Bonaire	1589	17	1566
# Butão	1687	1	1388
# Maurícia	1458	18	1206
# Antígua e Barbuda	1262	42	1214
# Guernsey	823	14	808
# Diamond Princess	712	14	698
# Tanzânia	0	0	0
# Ilhas Faroe	743	1	697
# Ilhas Cayman	587	2	575
# Fiji	687	4	193
# Ilhas Virgens Britânicas	292	1	285
# Brunei	244	3	231
# Dominica	188	0	187
# Ilhas Marianas Setentrionais	183	2	32
# Granada	160	1	158
# Costa Atlantica	148	0	148
# Greg Mortimer	128	1	0
# Nova Caledônia	128	0	30
# Anguilla	109	0	109
# São Vicente e Granadinas	98	0	81
# Ilhas Malvinas	63	0	63
# São Cristóvão e Neves	78	0	48
# Macau	51	0	49
# Gronelândia	43	0	34
# Vaticano	29	0	27
# Saint Pierre e Miquelon	25	0	25
# Santo Eustáquio	20	0	20
# Montserrat	20	1	18
# MS Zaandam	13	4	0
# Coral Princess	12	3	0
# Saba	7	0	7

# %% [markdown]
# ## Gravando o texto em um arquivo

# %% [markdown]
# Para se gravar o texto em um arquivo, basta utilizar o código a seguir.

# %%
arquivo = open("lista-paises.tsv", "w")
arquivo.write(texto_final)
arquivo.close()

# %% [markdown]
# ### Lendo o arquivo CSV com o Pandas

# %%
import pandas as pd
df = pd.read_csv("lista-paises.tsv", sep='\t')
df
# Out:
#                 País     Casos  Mortes   Curados
# 0     Estados Unidos  33503141  602805         0
# 1              Índia  26752447  303720  23728011
# 2             Brasil  16907425  472531  15290500
# 3             França   5707683  110002         0
# 4            Turquia   5287980   48164   5160774
# ..               ...       ...     ...       ...
# 220  Santo Eustáquio        20       0        20
# 221       Montserrat        20       1        18
# 222       MS Zaandam        13       4         0
# 223   Coral Princess        12       3         0
# 224             Saba         7       0         7
#
# [225 rows x 4 columns]

# %% [markdown]
# ### Indonésia

# %%
df[df['País'] == 'Indonésia']
# Out:
#          País      Casos  Mortes    Curados
# 20  Indonésia  1 511 712  40 858  1 348 330

# %% [markdown]
# A função lambda é uma função anônima (sem nome), em que o parâmetro é designado por celula. A função é aplicada sobre cada célula da coluna. Assim para cada célula, a função replace será executada.

# %%
df['Casos'] = df.Casos.apply(lambda celula: celula.replace(" ", ""))
df['Mortes'] = df.Mortes.apply(lambda celula: celula.replace(" ", ""))
df['Curados'] = df.Curados.apply(lambda celula: celula.replace(" ", ""))

# %%
df[df['País'] == 'Indonésia']
# Out:
#          País    Casos Mortes  Curados
# 20  Indonésia  1511712  40858  1348330

# %% [markdown]
# **Convertendo para tipos numéricos**

# %% [markdown]
# Se tudo correr bem nessa conversão, é porque tudo foi tratado adequadamente. Caso ocorra problemas aqui, você deve inspecionar a tabela para encontrar onde estão os problemas.

# %%
df['Casos'] = df.Casos.astype(int)
df['Mortes'] = df.Mortes.astype(int)
df['Curados'] = df.Curados.astype(int)

# %% [markdown]
# ### Tarefas

# %%
df
# Out:
#                 País     Casos  Mortes   Curados
# 0     Estados Unidos  33503141  602805         0
# 1              Índia  26752447  303720  23728011
# 2             Brasil  16907425  472531  15290500
# 3             França   5707683  110002         0
# 4            Turquia   5287980   48164   5160774
# ..               ...       ...     ...       ...
# 220  Santo Eustáquio        20       0        20
# 221       Montserrat        20       1        18
# 222       MS Zaandam        13       4         0
# 223   Coral Princess        12       3         0
# 224             Saba         7       0         7
#
# [225 rows x 4 columns]

# %% [markdown]
# 1) Utilizando o plotly, faça a análise da evolução de Casos, Mortes e Curados do Dataset.

# %%
import plotly.express as px

# %%
fig1 = px.bar(df[:10], x="País", y="Casos", title="Os 10 países com mais casos de COVID-19")
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="54dbb859-94cc-401e-8f51-e8f44cb62c94" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54dbb859-94cc-401e-8f51-e8f44cb62c94")) {
#                     Plotly.newPlot(
#                         '54dbb859-94cc-401e-8f51-e8f44cb62c94',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Casos=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Estados Unidos", "\u00cdndia", "Brasil", "Fran\u00e7a", "Turquia", "R\u00fassia", "Reino Unido", "It\u00e1lia", "Argentina", "Espanha"], "xaxis": "x", "y": [33503141, 26752447, 16907425, 5707683, 5287980, 5126437, 4516892, 4230153, 3938961, 3697987], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
df_mortes = df.sort_values(by="Mortes", ascending=False)
fig2 = px.bar(df_mortes[:10], x="País", y="Mortes", title="Os 10 países com mais mortes por COVID-19")
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8448e0ca-217b-455b-8d66-38d35364f449" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8448e0ca-217b-455b-8d66-38d35364f449")) {
#                     Plotly.newPlot(
#                         '8448e0ca-217b-455b-8d66-38d35364f449',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Mortes=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Estados Unidos", "Brasil", "\u00cdndia", "M\u00e9xico", "Peru", "Reino Unido", "It\u00e1lia", "R\u00fassia", "Fran\u00e7a", "Col\u00f4mbia"], "xaxis": "x", "y": [602805, 472531, 303720, 228754, 186073, 127840, 126472, 123787, 110002, 90890], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
df_curados = df.sort_values(by="Curados", ascending=False)
fig3 = px.bar(df_curados[:10], x="País", y="Curados", title="Os 10 países com mais curados de COVID-19")
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="39ef1a28-cf58-41d1-8c9d-571c7f6d3e1c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("39ef1a28-cf58-41d1-8c9d-571c7f6d3e1c")) {
#                     Plotly.newPlot(
#                         '39ef1a28-cf58-41d1-8c9d-571c7f6d3e1c',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Curados=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["\u00cdndia", "Brasil", "Turquia", "R\u00fassia", "It\u00e1lia", "Alemanha", "Argentina", "Col\u00f4mbia", "Pol\u00f4nia", "Ir\u00e3"], "xaxis": "x", "y": [23728011, 15290500, 5160774, 4736446, 3908312, 3533648, 3497437, 3267100, 2645150, 2522702], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpo ...

# %%
#excluindo países que apresentem número de casos, mortes ou curados == 0
df_dispersao = df.loc[(df.Mortes != 0) & (df.Curados != 0) & (df.Casos != 0)]
fig4 = px.scatter(df_dispersao, x="Casos", y="Mortes", title="Relação entre casos e mortes de COVID-19 por País", hover_name="País", color="País")
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bef85bc0-8f33-4e81-8799-9df837f12882" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bef85bc0-8f33-4e81-8799-9df837f12882")) {
#                     Plotly.newPlot(
#                         'bef85bc0-8f33-4e81-8799-9df837f12882',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Pa\u00eds=\u00cdndia<br>Casos=%{x}<br>Mortes=%{y}", "hovertext": ["\u00cdndia"], "legendgroup": "Pa\u00eds=\u00cdndia", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Pa\u00eds=\u00cdndia", "showlegend": true, "type": "scatter", "x": [26752447], "xaxis": "x", "y": [303720], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Pa\u00eds=Brasil<br>Casos=%{x}<br>Mortes=%{y}", "hovertext": ["Brasil"], "legendgroup": "Pa\u00eds=Brasil", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Pa\u00eds=Brasil", "showlegend": true, "type": "scatter", "x": [16907425], "xaxis": "x", "y": [472531], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Pa\u00eds=Turquia<br>Casos=%{x}<br>Mortes=%{y}", "hovertext": ["Turquia"], "legendgroup": "Pa\u00eds=Turquia", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "Pa\u00eds=Turquia", "showlegend": true, "type": "scatter", "x": [5287980], "xaxis": "x", "y": [48164], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Pa\u00eds=R\u00fassia<br>Casos=%{x}<br>Mortes=%{y}", "hovertext": ["R\u00fassia"], "legendgroup": "Pa\u00eds=R\u00fassia", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Pa\u00eds=R\u00fassia", "showlegend": true, "type": "scatter", "x": [5126437], "xaxis": "x", "y": [123787], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Pa\u00eds=It\u00e1lia<br>Casos=%{x}<br>Mortes=%{y}", "hovertext": ["It\u00e1lia"], "legendgroup": "Pa\u00eds=It\u00e1lia", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Pa\u00eds=It\u00e1lia", "showlegend": true, "type": "scatter", "x": [4230153], "xaxis": "x", "y": [126472], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Pa\u00eds=Argentina<br>Casos=%{x}<br>Mortes=%{y}", "hovertext": ["Argentina"], "legendgroup": "Pa\u00eds=Argentina", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "markers", "name": "Pa\u00eds=Argentina", "showlegend": true, "type": "scatter", "x": [3938961], "xaxis": "x", "y": [80867], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Pa\u00eds=Alemanha<br>Casos=%{x}<br>Mortes=%{y}", "hovertext": ["Alemanha"], "legendgroup": "Pa\u00eds=Alemanha", "marker": {"color": "#FF6692", "symbol": "circle"}, "mode": "markers", "name": "Pa\u00eds=Alemanha", "showlegend": true, "type": "scatter", "x": [3717890], "xaxis": "x", "y": [89825], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Pa\u00eds=Col\u00f4mbia<br>Casos=%{x}<br>Mortes=%{y}", "hovertext": ["Col\u00f4mbia"], "legendgroup": "Pa\u00eds=Col\u00f4mbia", "marker": {"color": "#B6E880", "symbol": "circle"}, "mode": "markers", "name": "Pa\u00eds=Col\u00f4mbia", "showlegend": true, "type": "scatter", "x": [3518046], "xaxis": "x", "y": [90890], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Pa\u00eds=Ir\u00e3<br>Casos=%{x}<br>Mortes=%{y}", "hovertext": ["Ir\u00e3"], "legendgroup": "Pa\u00eds=Ir\u00e3", "marker": {"color": "#FF97FF", "symbol": "circle"}, "mode": "markers", "name": "Pa\u00eds=Ir\u00e3", "showlegend": true, "type": "scatter", "x": [2954309], "xaxis": "x", "y": [80813], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>Pa\u00eds=Pol\u00f4nia<br>Casos=%{x}<br>Mortes=%{y}", "hovertext": ["Pol\u00f4nia"], "legendgroup": "Pa\u00eds=Pol\u00f4nia", "marker": {"color": "#FECB52", "symbol": "circle"}, "mode": "markers", "name": "Pa\u00eds=Pol\u00f4nia", "showlegend": true, "type": "scatter", "x": [2875136], "xaxis": "x", "y": [74152], "yax ...

# %% [markdown]
# 2) Calcule a estatística descritiva (média, soma, mediana e desvio-padrão) dos países do dataset.

# %%
df.Mortes.describe()
# Out:
# count       225.000000
# mean      16362.488889
# std       60765.311395
# min           0.000000
# 25%          86.000000
# 50%         818.000000
# 75%        5448.000000
# max      602805.000000
# Name: Mortes, dtype: float64

# %%
print("Estatísticas sobre o número de mortes:")
print(f"Média: {round(df.Mortes.describe()[1])} mortos")
print(f"Total de mortos: {df.Mortes.sum()} mortos")
print(f"Mediana do total de mortos por país: {df.Mortes.describe()[5]} mortos")
print(f"Desvio Padrão do total de mortos por país: {round(df.Mortes.describe()[2])} mortos")
# Out:
# Estatísticas sobre o número de mortes:
# Média: 16362 mortos
# Total de mortos: 3681560 mortos
# Mediana do total de mortos por país: 818.0 mortos
# Desvio Padrão do total de mortos por país: 60765 mortos

# %%
print("Estatísticas sobre o número de casos:")
print(f"Média: {round(df.Casos.describe()[1])} casos")
print(f"Total de casos: {df.Casos.sum()} casos")
print(f"Mediana do total de casos por país: {df.Casos.describe()[5]} casos")
print(f"Desvio Padrão do total de casos por país: {round(df.Casos.describe()[2])} casos")
# Out:
# Estatísticas sobre o número de casos:
# Média: 759434 casos
# Total de casos: 170872610 casos
# Mediana do total de casos por país: 48901.0 casos
# Desvio Padrão do total de casos por país: 3161962 casos

# %% [markdown]
# 3) Encontre uma tabela na Wikipedia do seu interesse e aplique as técnicas apresentadas neste caderno para criar um DataFrame, criar gráficos no Plotly e fazer as estatísticas descritivas.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import plotly.express as px
import requests
import re

# %%
url = "https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_and_territory"
page2 = requests.get(url)
page2
# Out:
# <Response [200]>

# %%
soup2 = BeautifulSoup(page2.content, "html.parser")
table = soup2.find(attrs={"aria-label":"COVID-19 pandemic mortality and death rates by country table"}).table.tbody

# %%
table_lines = table.find_all("tr")
table_lines[1].text
# Out:
# '\n\xa0Peru\n1,980,391\n186,073\n9.40%\n572.35\n'

# %%
def consertar_linha(row):
  row = row.replace("\xa0", "")
  row = row.strip("\n")
  row = re.sub("\n+", "\t", row)
  return row

# %%
consertar_linha(table_lines[1].text)
# Out:
# 'Peru\t1,980,391\t186,073\t9.40%\t572.35'

# %%
dataset = "País\tCasos Confirmados\tMortes\tTaxa de Fatalidade\tMortes por cem mil hab.\n"
for line in table_lines[1:]:
  dataset += consertar_linha(line.text)
  if line != table_lines[-1]:
    dataset += "\n"
print(dataset)
# Out:
# País	Casos Confirmados	Mortes	Taxa de Fatalidade	Mortes por cem mil hab.
# Peru	1,980,391	186,073	9.40%	572.35
# Hungary	806,008	29,854	3.70%	305.57
# Bosnia and Herzegovina	204,304	9,374	4.60%	283.97
# Czech Republic	1,663,517	30,159	1.80%	282.66
# San Marino	5,090	90	1.80%	265.80
# North Macedonia	155,417	5,455	3.50%	261.82
# Montenegro	99,812	1,592	1.60%	255.89
# Bulgaria	419,473	17,820	4.20%	255.46
# Moldova	255,453	6,134	2.40%	230.81
# Slovakia	390,436	12,404	3.20%	227.43
# Brazil	16,947,062	473,404	2.80%	224.31
# Belgium	1,070,802	25,033	2.30%	217.98
# Slovenia	255,375	4,388	1.70%	210.16
# Italy	4,232,428	126,523	3.00%	209.83
# Croatia	357,565	8,086	2.30%	198.80
# Poland	2,875,136	74,152	2.60%	195.29
# United Kingdom	4,532,802	128,103	2.80%	191.67
# Colombia	3,571,067	91,961	2.60%	182.68
# United States	33,362,600	597,628	1.80%	182.07
# Argentina	3,955,439	81,214	2.10%	180.72
# Mexico	2,433,681	228,804	9.40%	179.35
# Spain	3,697,981	80,196	2.20%	170.35
# Portugal	852,646	17,034	2.00%	165.87
# Andorra	13,758	127	0.90%	164.63
# France	5,774,361	110,160	1.90%	164.27
# Romania	1,078,863	30,815	2.90%	159.20
# Chile	1,427,956	29,937	2.10%	157.96
# Lithuania	276,453	4,307	1.60%	154.55
# Liechtenstein	3,022	58	1.90%	152.56
# Panama	382,475	6,402	1.70%	150.76
# Armenia	223,180	4,458	2.00%	150.72
# Sweden	1,078,062	14,523	1.30%	141.20
# Paraguay	373,165	9,874	2.60%	140.16
# Uruguay	316,535	4,640	1.50%	134.04
# Georgia	349,098	4,910	1.40%	131.98
# Luxembourg	70,182	818	1.20%	131.96
# Bolivia	387,162	15,024	3.90%	130.49
# Switzerland	697,292	10,832	1.60%	126.32
# Latvia	134,812	2,413	1.80%	126.15
# Kosovo	107,058	2,249	2.10%	125.34
# Ukraine	2,273,708	53,258	2.30%	119.99
# Austria	646,800	10,639	1.60%	119.85
# Ecuador	432,353	20,809	4.80%	119.77
# Greece	409,368	12,277	3.00%	114.56
# Lebanon	541,557	7,763	1.40%	113.23
# Tunisia	355,732	12,980	3.60%	110.99
# Germany	3,708,898	89,249	2.40%	107.36
# Netherlands	1,690,481	17,954	1.10%	103.58
# Ireland	264,498	4,941	1.90%	99.99
# Serbia	713,678	6,917	1.00%	99.60
# Iran	2,966,363	81,063	2.70%	97.77
# South Africa	1,696,564	56,974	3.40%	97.29
# Estonia	130,119	1,263	1.00%	95.21
# Jordan	739,847	9,530	1.30%	94.34
# Albania	132,379	2,451	1.90%	85.87
# Monaco	2,508	33	1.30%	84.69
# Russia	5,067,246	121,711	2.40%	84.30
# Malta	30,571	419	1.40%	83.36
# Belize	12,861	325	2.50%	83.26
# Costa Rica	327,979	4,153	1.30%	82.28
# Palestine	310,026	3,517	1.10%	75.06
# Israel	839,571	6,418	0.80%	70.89
# Canada	1,400,093	25,694	1.80%	68.35
# Bahrain	251,078	1,119	0.40%	68.18
# Honduras	241,826	6,479	2.70%	66.48
# Suriname	16,541	350	2.10%	60.20
# Bahamas	11,930	232	1.90%	59.57
# Eswatini	18,653	673	3.60%	58.62
# Turkey	5,287,980	48,164	0.90%	57.73
# Guyana	17,665	409	2.30%	52.25
# Guatemala	261,958	8,294	3.20%	49.95
# Azerbaijan	334,715	4,941	1.50%	49.30
# Cape Verde	31,097	267	0.90%	48.55
# Oman	223,879	2,413	1.10%	48.50
# Libya	187,281	3,143	1.70%	46.37
# Saint Lucia	5,133	80	1.60%	43.77
# Denmark	287,275	2,519	0.90%	43.29
# Antigua and Barbuda	1,263	42	3.30%	43.25
# Seychelles	12,158	42	0.30%	43.02
# Kuwait	317,197	1,795	0.60%	42.67
# Iraq	1,224,992	16,538	1.40%	42.07
# Trinidad and Tobago	26,410	577	2.20%	41.36
# Botswana	56,217	866	1.50%	37.59
# Namibia	58,707	912	1.60%	36.56
# El Salvador	74,141	2,270	3.10%	35.17
# Maldives	67,950	185	0.30%	34.84
# Dominican Republic	301,078	3,654	1.20%	34.03
# Jamaica	48,810	960	2.00%	32.56
# Belarus	399,852	2,910	0.70%	30.74
# Cyprus	72,779	363	0.50%	30.29
# Kyrgyzstan	106,973	1,847	1.70%	28.61
# Nepal	588,124	7,898	1.30%	27.61
# India	28,909,975	349,186	1.20%	25.55
# Morocco	521,426	9,178	1.80%	25.16
# Saudi Arabia	457,546	7,456	1.60%	21.76
# Philippines	1,269,478	21,898	1.70%	20.25
# Qatar	218,627	569	0.30%	20.09
# Indonesia	1,856,038	51,612	2.80%	19.07
# Kazakhstan	450,868	3,473	0.80%	18.76
# United Arab Emirates	583,071	1,699	0.30%	17.39
# Finland	93,226	959	1.00%	17.37
# São Tomé and Príncipe	2,353	37	1.60%	17.20
# Comoros	3,888	146	3.80%	17.16
# Barbados	4,031	47	1.20%	16.37
# Djibouti	11,562	154	1.30%	15.82
# Lesotho	10,837	326	3.00%	15.34
# Egypt	267,972	15,352	5.70%	15.29
# Congo	33,202	804	2.40%	14.94
# Norway	126,817	785	0.60%	14.68
# Zimbabwe	39,189	1,606	4.10%	10.97
# Saint Vincent and the Grenadines	2,076	12	0.60%	10.85
# Japan	762,980	13,531	1.80%	10.72
# Malaysia	616,815	3,378	0.50%	10.57
# Syria	24,659	1,793	7.30%	10.50
# Mauritania	19,817	468	2.40%	10.34
# Pakistan	933,630	21,323	2.30%	9.85
# Mongolia	66,443	313	0.50%	9.70
# Venezuela	242,138	2,719	1.10%	9.54
# Cuba	148,918	1,012	0.70%	8.93
# Equatorial Guinea	8,626	118	1.40%	8.70
# Afghanistan	79,224	3,145	4.00%	8.27
# Algeria	130,958	3,518	2.70%	8.17
# Iceland	6,555	29	0.40%	8.03
# Bangladesh	810,990	12,839	1.60%	7.87
# Sri Lanka	205,333	1,696	0.80%	7.78
# Gambia	5,999	179	3.00%	7.62
# Zambia	100,278	1,308	1.30%	7.32
# Gabon	24,591	154	0.60%	7.09
# Senegal	41,680	1,146	2.70%	7.03
# Sudan	35,656	2,697	7.60%	6.30
# Kenya	172,491	3,287	1.90%	6.25
# Malawi	34,390	1,157	3.40%	6.21
# Myanmar	144,317	3,225	2.20%	5.97
# Somalia	14,748	773	5.20%	5.01
# Cameroon	78,929	1,275	1.60%	4.93
# Yemen	6,787	1,329	19.60%	4.56
# South Korea	144,637	1,974	1.40%	3.82
# Ethiopia	272,914	4,209	1.50%	3.76
# Australia	30,191	910	3.00%	3.59
# Guinea-Bissau	3,787	68	1.80%	3.54
# Madagascar	41,690	861	2.10%	3.19
# Haiti	15,282	323	2.10%	2.87
# Nicaragua	7,481	187	2.50%	2.86
# Rwanda	27,245	360	1.30%	2.85
# Mozambique	71,114	837	1.20%	2.76
# Mali	14,298	519	3.60%	2.64
# Ghana	94,228	787	0.80%	2.59
# Angola	35,772	797	2.20%	2.50
# Central African Republic	7,091	98	1.40%	2.07
# Uzbekistan	101,722	696	0.70%	2.07
# Papua New Guinea	16,327	164	1.00%	1.87
# Thailand	177,467	1,236	0.70%	1.78
# Liberia	2,250	86	3.80%	1.74
# Cambodia	34,244	263	0.80%	1.60
# Togo	13,539	125	0.90%	1.55
# Mauritius	1,458	18	1.20%	1.42
# East Timor	7,740	17	0.20%	1.31
# Guinea	23,255	162	0.70%	1.27
# Ivory Coast	47,490	306	0.60%	1.19
# Chad	4,939	174	3.50%	1.09
# Taiwan	11,298	260	2.30%	1.09
# Nigeria	166,767	2,117	1.30%	1.05
# South Sudan	10,688	115	1.10%	1.04
# Sierra Leone	4,201	79	1.90%	1.01
# Tajikistan	13,308	90	0.70%	0.97
# Uganda	52,935	383	0.70%	0.87
# Benin	8,082	102	1.30%	0.86
# Burkina Faso	13,453	167	1.20%	0.82
# Niger	5,439	192	3.50%	0.82
# Brunei	244	3	1.20%	0.69
# Singapore	62,196	33	0.10%	0.58
# New Zealand	2,682	26	1.00%	0.53
# Fiji	687	4	0.60%	0.45
# China	103,176	4,846	4.70%	0.35
# DR Congo	11,920	155	1.30%	0.18
# Burundi	4,905	8	0.20%	0.07
# Vietnam	8,791	53	0.60%	0.05
# Tanzania	509	21	4.10%	0.04
# Laos	1,963	3	0.20%	0.04
# Eritrea	4,427	14	0.30%	nan

# %%
arquivo2 = open("Dados_covid_relativos.tsv", "w")
arquivo2.write(dataset)
arquivo2.close()

# %%
df_new = pd.read_csv("Dados_covid_relativos.tsv", sep="\t").sort_values(by="Mortes por cem mil hab.", ascending=False)
df_new
# Out:
#                        País  ... Mortes por cem mil hab.
# 0                      Peru  ...                  572.35
# 1                   Hungary  ...                  305.57
# 2    Bosnia and Herzegovina  ...                  283.97
# 3            Czech Republic  ...                  282.66
# 4                San Marino  ...                  265.80
# ..                      ...  ...                     ...
# 175                 Burundi  ...                    0.07
# 176                 Vietnam  ...                    0.05
# 177                Tanzania  ...                    0.04
# 178                    Laos  ...                    0.04
# 179                 Eritrea  ...                     NaN
#
# [180 rows x 5 columns]

# %%
fig5 = px.bar(df_new[:10], x="País", y="Mortes por cem mil hab.", color="País", title="Os 10 países com mais mortes por cem mil hab.")
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="09e366a1-be33-43b1-aefa-99f8c7da846b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("09e366a1-be33-43b1-aefa-99f8c7da846b")) {
#                     Plotly.newPlot(
#                         '09e366a1-be33-43b1-aefa-99f8c7da846b',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Mortes por cem mil hab.=%{y}", "legendgroup": "Pa\u00eds=Peru", "marker": {"color": "#636efa"}, "name": "Pa\u00eds=Peru", "offsetgroup": "Pa\u00eds=Peru", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Peru"], "xaxis": "x", "y": [572.35], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Mortes por cem mil hab.=%{y}", "legendgroup": "Pa\u00eds=Hungary", "marker": {"color": "#EF553B"}, "name": "Pa\u00eds=Hungary", "offsetgroup": "Pa\u00eds=Hungary", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Hungary"], "xaxis": "x", "y": [305.57], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Mortes por cem mil hab.=%{y}", "legendgroup": "Pa\u00eds=Bosnia and Herzegovina", "marker": {"color": "#00cc96"}, "name": "Pa\u00eds=Bosnia and Herzegovina", "offsetgroup": "Pa\u00eds=Bosnia and Herzegovina", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bosnia and Herzegovina"], "xaxis": "x", "y": [283.97], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Mortes por cem mil hab.=%{y}", "legendgroup": "Pa\u00eds=Czech Republic", "marker": {"color": "#ab63fa"}, "name": "Pa\u00eds=Czech Republic", "offsetgroup": "Pa\u00eds=Czech Republic", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Czech Republic"], "xaxis": "x", "y": [282.66], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Mortes por cem mil hab.=%{y}", "legendgroup": "Pa\u00eds=San Marino", "marker": {"color": "#FFA15A"}, "name": "Pa\u00eds=San Marino", "offsetgroup": "Pa\u00eds=San Marino", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["San Marino"], "xaxis": "x", "y": [265.8], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Mortes por cem mil hab.=%{y}", "legendgroup": "Pa\u00eds=North Macedonia", "marker": {"color": "#19d3f3"}, "name": "Pa\u00eds=North Macedonia", "offsetgroup": "Pa\u00eds=North Macedonia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["North Macedonia"], "xaxis": "x", "y": [261.82], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Mortes por cem mil hab.=%{y}", "legendgroup": "Pa\u00eds=Montenegro", "marker": {"color": "#FF6692"}, "name": "Pa\u00eds=Montenegro", "offsetgroup": "Pa\u00eds=Montenegro", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Montenegro"], "xaxis": "x", "y": [255.89], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Mortes por cem mil hab.=%{y}", "legendgroup": "Pa\u00eds=Bulgaria", "marker": {"color": "#B6E880"}, "name": "Pa\u00eds=Bulgaria", "offsetgroup": "Pa\u00eds=Bulgaria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bulgaria"], "xaxis": "x", "y": [255.46], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Mortes por cem mil hab.=%{y}", "legendgroup": "Pa\u00eds=Moldova", "marker": {"color": "#FF97FF"}, "name": "Pa\u00eds=Moldova", "offsetgroup": "Pa\u00eds=Moldova", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Moldova"], "xaxis": "x", "y": [230.81], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Mortes por cem mil hab.=%{y}", "legendgroup": "Pa\u00eds=Slovakia", "marker": {"color": "#FECB52"}, "name": "Pa\u00eds=Slovakia", "offs ...
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f

# %%
fig6 = px.bar(df_new[:10].sort_values(by="Taxa de Fatalidade", ascending=False), x="País", y="Taxa de Fatalidade", color="País", title="Os 10 países com maior taxa de fatalidade em percentual.")
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8fbbd68c-d746-4aec-9b2e-9b6afba8b9ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8fbbd68c-d746-4aec-9b2e-9b6afba8b9ae")) {
#                     Plotly.newPlot(
#                         '8fbbd68c-d746-4aec-9b2e-9b6afba8b9ae',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Taxa de Fatalidade=%{y}", "legendgroup": "Pa\u00eds=Peru", "marker": {"color": "#636efa"}, "name": "Pa\u00eds=Peru", "offsetgroup": "Pa\u00eds=Peru", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Peru"], "xaxis": "x", "y": ["9.40%"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Taxa de Fatalidade=%{y}", "legendgroup": "Pa\u00eds=Bosnia and Herzegovina", "marker": {"color": "#EF553B"}, "name": "Pa\u00eds=Bosnia and Herzegovina", "offsetgroup": "Pa\u00eds=Bosnia and Herzegovina", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bosnia and Herzegovina"], "xaxis": "x", "y": ["4.60%"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Taxa de Fatalidade=%{y}", "legendgroup": "Pa\u00eds=Bulgaria", "marker": {"color": "#00cc96"}, "name": "Pa\u00eds=Bulgaria", "offsetgroup": "Pa\u00eds=Bulgaria", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Bulgaria"], "xaxis": "x", "y": ["4.20%"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Taxa de Fatalidade=%{y}", "legendgroup": "Pa\u00eds=Hungary", "marker": {"color": "#ab63fa"}, "name": "Pa\u00eds=Hungary", "offsetgroup": "Pa\u00eds=Hungary", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Hungary"], "xaxis": "x", "y": ["3.70%"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Taxa de Fatalidade=%{y}", "legendgroup": "Pa\u00eds=North Macedonia", "marker": {"color": "#FFA15A"}, "name": "Pa\u00eds=North Macedonia", "offsetgroup": "Pa\u00eds=North Macedonia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["North Macedonia"], "xaxis": "x", "y": ["3.50%"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Taxa de Fatalidade=%{y}", "legendgroup": "Pa\u00eds=Slovakia", "marker": {"color": "#19d3f3"}, "name": "Pa\u00eds=Slovakia", "offsetgroup": "Pa\u00eds=Slovakia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Slovakia"], "xaxis": "x", "y": ["3.20%"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Taxa de Fatalidade=%{y}", "legendgroup": "Pa\u00eds=Moldova", "marker": {"color": "#FF6692"}, "name": "Pa\u00eds=Moldova", "offsetgroup": "Pa\u00eds=Moldova", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Moldova"], "xaxis": "x", "y": ["2.40%"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Taxa de Fatalidade=%{y}", "legendgroup": "Pa\u00eds=Czech Republic", "marker": {"color": "#B6E880"}, "name": "Pa\u00eds=Czech Republic", "offsetgroup": "Pa\u00eds=Czech Republic", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Czech Republic"], "xaxis": "x", "y": ["1.80%"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Taxa de Fatalidade=%{y}", "legendgroup": "Pa\u00eds=San Marino", "marker": {"color": "#FF97FF"}, "name": "Pa\u00eds=San Marino", "offsetgroup": "Pa\u00eds=San Marino", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["San Marino"], "xaxis": "x", "y": ["1.80%"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Pa\u00eds=%{x}<br>Taxa de Fatalidade=%{y}", "legendgroup": "Pa\u00eds=Montenegro", "marker": {"color": "#FECB52"}, "name": "Pa\u00eds=Montenegro", "offsetgroup": "Pa\u00eds=Montenegro", "orientati ...
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}
